# %%
from datetime import datetime
import pandas as pd
import numpy as np
import requests
import json
from tqdm import tqdm
from time import sleep
# Para trabajar con archivos dotenv y los tokens
# -----------------------------------------------------------------------
import os
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
# Invocamos de forma segura la contraseña de rapidapi
key = os.getenv("token")

# %%
url = "https://tripadvisor-scraper.p.rapidapi.com/hotels/list"

querystring = {"query":"Barcelona", "limit":"50", "adults": "2"}

headers = {
	"x-rapidapi-key": key,
	"x-rapidapi-host": "tripadvisor-scraper.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

respuesta=response.json()

# %%
with open('hoteleles_barcelona.json', 'w') as archivo:
    json.dump(respuesta, archivo, indent=4)

# %%
respuesta
# Out:
# {'link': 'https://www.tripadvisor.com/Hotels-g187497-Barcelona_Catalonia-Hotels.html',
#  'total_pages': 73,
#  'current_page': 1,
#  'total_items_count': 2185,
#  'items_count': 31,
#  'results': [{'id': 2545026,
#    'name': 'Andante Hotel',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d2545026-Reviews-Andante_Hotel-Barcelona_Catalonia.html',
#    'reviews': 2817,
#    'rating': 4.5,
#    'price_range_usd': {'min': 150, 'max': 241},
#    'phone': '+34 934 41 25 45',
#    'address': 'Av. Drassanes, 23-25 Rambla Del Raval, 08001 Barcelona Spain',
#    'detailed_address': {'street': 'Av. Drassanes, 23-25, Rambla Del Raval',
#     'city': 'Barcelona',
#     'postal_code': '08001',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 91, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.37648,
#    'longitude': 2.172685,
#    'amenities': ['Free Wifi', 'Pool', 'Outdoor pool', 'Fitness center'],
#    'providers': ['Expedia.com', 'Booking.com', 'Hotels.com', 'ZenHotels.com']},
#   {'id': 630596,
#    'name': 'Hyatt Regency Barcelona Tower',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d630596-Reviews-Hyatt_Regency_Barcelona_Tower-Barcelona_Catalonia.html',
#    'reviews': 3566,
#    'rating': 4.5,
#    'price_range_usd': {'min': 187, 'max': 295},
#    'phone': '+34 934 13 50 00',
#    'address': 'Avinguda de la Granvia de l’Hospitalet, 144, 08907 Barcelona Spain',
#    'detailed_address': {'street': 'Avinguda de la Granvia de l’Hospitalet, 144',
#     'city': 'Barcelona',
#     'postal_code': '08907',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 56, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.346046,
#    'longitude': 2.108611,
#    'amenities': ['Free Wifi',
#     'Pool',
#     'Heated pool',
#     'Indoor pool',
#     'Restaurant'],
#    'providers': ['Expedia.com', 'Booking.com', 'Hotels.com', 'Vio.com']},
#   {'id': 228590,
#    'name': 'Hotel Astoria',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d228590-Reviews-Hotel_Astoria-Barcelona_Catalonia.html',
#    'reviews': 1900,
#    'rating': 4.5,
#    'price_range_usd': {'min': 118, 'max': 233},
#    'phone': '+34 932 09 83 11',
#    'address': 'Carrer de Paris, 203, 08036 Barcelona Spain',
#    'detailed_address': {'street': 'Carrer de Paris, 203',
#     'city': 'Barcelona',
#     'postal_code': '08036',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 115, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.393997,
#    'longitude': 2.153488,
#    'amenities': ['Free Wifi',
#     'Pool',
#     'Outdoor pool',
#     'Restaurant',
#     'Room service'],
#    'providers': ['Expedia.com',
#     'Official website',
#     'Booking.com',
#     'Skyscanner.com']},
#   {'id': 190616,
#    'name': 'Majestic Hotel & Spa Barcelona',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d190616-Reviews-Majestic_Hotel_Spa_Barcelona-Barcelona_Catalonia.html',
#    'reviews': 4259,
#    'rating': 4.5,
#    'price_range_usd': {'min': 339, 'max': 553},
#    'phone': '+34 934 88 17 17',
#    'address': 'Paseo de Gracia, 68 - 70, 08007 Barcelona Spain',
#    'detailed_address': {'street': 'Paseo de Gracia, 68 - 70',
#     'city': 'Barcelona',
#     'postal_code': '08007',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 71, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.393536,
#    'longitude': 2.163977,
#    'amenities': ['Free Wifi',
#     'Pool',
#     'Outdoor pool',
#     'Restaurant',
#     'Airport transportation'],
#    'providers': ['Expedia.com',
#     'Official website',
#     'Hotels.com',
#     'Skyscanner.com']},
#   {'id': 236194,
#    'name': 'Hotel Catalonia Park Güell',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d236194-Reviews-Hotel_Catalonia_Park_Guell-Barcelona_Catalonia.html',
#    'reviews': 1417,
#    'rating': 3.5,
#    'price_range_usd': {'min': 86, 'max': 185},
#    'phone': '+34 932 19 12 04',
#    'address': 'Passeig de la Mare de Deu del Coll, 10, 08023 Barcelona Spain',
#    'detailed_address': {'street': 'Passeig de la Mare de Deu del Coll, 10',
#     'city': 'Barcelona',
#     'postal_code': '08023',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 351, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.41435,
#    'longitude': 2.14482,
#    'amenities': ['Free Wifi',
#     'Outdoor pool',
#     'Restaurant',
#     'Room service',
#     'Pets Allowed'],
#    'providers': ['Expedia.com', 'Booking.com', 'Hotels.com', 'ZenHotels.com']},
#   {'id': 206920,
#    'name': 'NH Collection Barcelona Podium',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d206920-Reviews-NH_Collection_Barcelona_Podium-Barcelona_Catalonia.html',
#    'reviews': 1495,
#    'rating': 4.5,
#    'price_range_usd': {'min': 175, 'max': 318},
#    'phone': '+34 932 65 02 02',
#    'address': 'Carrer de Bailèn 4-6, 08010 Barcelona Spain',
#    'detailed_address': {'street': 'Carrer de Bailèn 4-6',
#     'city': 'Barcelona',
#     'postal_code': '08010',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 103, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.391624,
#    'longitude': 2.177928,
#    'amenities': ['Free Wifi',
#     'Pool',
#     'Outdoor pool',
#     'Restaurant',
#     'Room service'],
#    'providers': ['Expedia.com',
#     'NH Collection',
#     'Hotels.com',
#     'ZenHotels.com']},
#   {'id': 250390,
#    'name': 'Oriente Atiram Hotel',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d250390-Reviews-Oriente_Atiram_Hotel-Barcelona_Catalonia.html',
#    'reviews': 2480,
#    'rating': 4,
#    'price_range_usd': {'min': 136, 'max': 240},
#    'phone': '+34 933 02 25 58',
#    'address': 'Rambla Dels Caputxins, 45, 08002 Barcelona Spain',
#    'detailed_address': {'street': 'Rambla Dels Caputxins, 45',
#     'city': 'Barcelona',
#     'postal_code': '08002',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 318, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.379757,
#    'longitude': 2.174221,
#    'amenities': ['Free Wifi', 'Restaurant', 'Room service', 'Bar/Lounge'],
#    'providers': ['Expedia.com',
#     'Official website',
#     'Hotels.com',
#     'ZenHotels.com']},
#   {'id': 231529,
#    'name': 'Tres Torres Atiram Hotel',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d231529-Reviews-Tres_Torres_Atiram_Hotel-Barcelona_Catalonia.html',
#    'reviews': 581,
#    'rating': 4,
#    'price_range_usd': {'min': 114, 'max': 194},
#    'phone': '+34 934 17 73 00',
#    'address': 'Calle Calatrava, 32, 08017 Barcelona Spain',
#    'detailed_address': {'street': 'Calle Calatrava, 32',
#     'city': 'Barcelona',
#     'postal_code': '08017',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 164, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.399887,
#    'longitude': 2.130179,
#    'amenities': ['Free Wifi', 'Restaurant', 'Room service', 'Bar/Lounge'],
#    'providers': ['Expedia.com', 'Hotels.com', 'Booking.com', 'Lol.travel']},
#   {'id': 3533952,
#    'name': 'Travelodge Barcelona Poblenou',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d3533952-Reviews-Travelodge_Barcelona_Poblenou-Barcelona_Catalonia.html',
#    'reviews': 2625,
#    'rating': 4,
#    'price_range_usd': {'min': 87, 'max': 157},
#    'phone': '+34 936 24 18 02',
#    'address': 'Carrer Llull, 170, 08005 Barcelona Spain',
#    'detailed_address': {'street': 'Carrer Llull, 170',
#     'city': 'Barcelona',
#     'postal_code': '08005',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 223, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.40001,
#    'longitude': 2.201108,
#    'amenities': ['Restaurant', 'Bar/Lounge'],
#    'providers': ['Expedia.com',
#     'Booking.com',
#     'Hotels.com',
#     'Skyscanner.com']},
#   {'id': 10062222,
#    'name': 'Catalonia Magdalenes',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d10062222-Reviews-Catalonia_Magdalenes-Barcelona_Catalonia.html',
#    'reviews': 1564,
#    'rating': 5,
#    'price_range_usd': {'min': 196, 'max': 360},
#    'phone': '+34 934 81 35 17',
#    'address': 'Carrer de les Magdalenes,13,15, 08002 Barcelona Spain',
#    'detailed_address': {'street': 'Carrer de les Magdalenes,13,15',
#     'city': 'Barcelona',
#     'postal_code': '08002',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 5, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.386135,
#    'longitude': 2.174618,
#    'amenities': ['Free Wifi',
#     'Pool',
#     'Heated pool',
#     'Outdoor pool',
#     'Restaurant'],
#    'providers': ['Expedia.com', 'Booking.com', 'Hotels.com', 'ZenHotels.com']},
#   {'id': 13223478,
#    'name': 'H10 Madison',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d13223478-Reviews-H10_Madison-Barcelona_Catalonia.html',
#    'reviews': 1289,
#    'rating': 5,
#    'price_range_usd': {'min': 202, 'max': 419},
#    'phone': '+34 932 38 21 37',
#    'address': 'C/ Dr. Joaquim Pou, 2-4-6 Ciutat Vella, 08002 Barcelona Spain',
#    'detailed_address': {'street': 'C/ Dr. Joaquim Pou, 2-4-6, Ciutat Vella',
#     'city': 'Barcelona',
#     'postal_code': '08002',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 11, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.386047,
#    'longitude': 2.175439,
#    'amenities': ['Free Wifi',
#     'Pool',
#     'Outdoor pool',
#     'Restaurant',
#     'Room service'],
#    'providers': ['Expedia.com',
#     'Booking.com',
#     'Hotels.com',
#     'Skyscanner.com']},
#   {'id': 19092478,
#    'name': 'Seventy Barcelona',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d19092478-Reviews-Seventy_Barcelona-Barcelona_Catalonia.html',
#    'reviews': 1204,
#    'rating': 5,
#    'price_range_usd': {'min': 226, 'max': 455},
#    'phone': '+34 930 12 12 70',
#    'address': 'Carrer Còrsega 344-352, 08037 Barcelona Spain',
#    'detailed_address': {'street': 'Carrer Còrsega 344-352',
#     'city': 'Barcelona',
#     'postal_code': '08037',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 6, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.398075,
#    'longitude': 2.161559,
#    'amenities': ['Free Wifi',
#     'Pool',
#     'Indoor pool',
#     'Restaurant',
#     'Room service'],
#    'providers': ['Hotels.com', 'Expedia.com', 'Skyscanner.com', 'Trip.com']},
#   {'id': 229676,
#    'name': 'Catalonia Barcelona Plaza',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d229676-Reviews-Catalonia_Barcelona_Plaza-Barcelona_Catalonia.html',
#    'reviews': 3911,
#    'rating': 4,
#    'price_range_usd': {'min': 142, 'max': 316},
#    'phone': '+34 934 26 26 00',
#    'address': 'Plaza Espana 6-8, 08014 Barcelona Spain',
#    'detailed_address': {'street': 'Plaza Espana 6-8',
#     'city': 'Barcelona',
#     'postal_code': '08014',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 237, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.375607,
#    'longitude': 2.148524,
#    'amenities': ['Free Wifi',
#     'Pool',
#     'Outdoor pool',
#     'Restaurant',
#     'Room service'],
#    'providers': ['Expedia.com', 'Booking.com', 'Hotels.com', 'ZenHotels.com']},
#   {'id': 1465497,
#    'name': 'W Barcelona',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d1465497-Reviews-W_Barcelona-Barcelona_Catalonia.html',
#    'reviews': 8294,
#    'rating': 4,
#    'price_range_usd': {'min': 322, 'max': 660},
#    'phone': '+34 932 95 28 00',
#    'address': 'Plaça Rosa del Vents 1 Final Passeig De Joan De Borbó, 08039 Barcelona Spain',
#    'detailed_address': {'street': 'Plaça Rosa del Vents 1, Final Passeig De Joan De Borbó',
#     'city': 'Barcelona',
#     'postal_code': '08039',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 301, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.36845,
#    'longitude': 2.190151,
#    'amenities': ['Free Wifi',
#     'Beachfront',
#     'Pool',
#     'Outdoor pool',
#     'Restaurant'],
#    'providers': ['Expedia.com',
#     'Booking.com',
#     'Hotels.com',
#     'Skyscanner.com']},
#   {'id': 232778,
#    'name': 'Hotel Arc La Rambla',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d232778-Reviews-Hotel_Arc_La_Rambla-Barcelona_Catalonia.html',
#    'reviews': 3698,
#    'rating': 4.5,
#    'price_range_usd': {'min': 125, 'max': 233},
#    'phone': '+34 933 01 97 98',
#    'address': 'La Rambla, 19, 08002 Barcelona Spain',
#    'detailed_address': {'street': 'La Rambla, 19',
#     'city': 'Barcelona',
#     'postal_code': '08002',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 153, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.378223,
#    'longitude': 2.175595,
#    'amenities': ['Free Wifi'],
#    'providers': ['Official website',
#     'Skyscanner.com',
#     'StayForLong',
#     'Booking.com']},
#   {'id': 3540235,
#    'name': 'Generator Barcelona',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d3540235-Reviews-Generator_Barcelona-Barcelona_Catalonia.html',
#    'reviews': 2388,
#    'rating': 4,
#    'price_range_usd': {'min': 63, 'max': 206},
#    'phone': '+34 932 20 03 77',
#    'address': 'Carrer De Còrsega, 373, 08037 Barcelona Spain',
#    'detailed_address': {'street': 'Carrer De Còrsega, 373',
#     'city': 'Barcelona',
#     'postal_code': '08037',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 87, 'total': 863},
#    'featured_image': None,
#    'latitude': 41.39916,
#    'longitude': 2.162623,
#    'amenities': ['Free Wifi', 'Restaurant', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'Hotels.com', 'Expedia.com', 'Official Site']},
#   {'id': 23462515,
#    'name': 'Castell Beach Aparthotel',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d23462515-Reviews-Castell_Beach_Aparthotel-Barcelona_Catalonia.html',
#    'reviews': 5,
#    'rating': 4.5,
#    'price_range_usd': {'min': 78, 'max': 128},
#    'phone': '+34 616 67 79 63',
#    'address': 'Avinguda Castelldefels, 191-193, 08860 Barcelona Spain',
#    'detailed_address': {'street': 'Avinguda Castelldefels, 191-193',
#     'city': 'Barcelona',
#     'postal_code': '08860',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': None,
#    'featured_image': None,
#    'latitude': 41.26851,
#    'longitude': 1.971649,
#    'amenities': ['Beachfront', 'Outdoor pool'],
#    'providers': ['Booking.com',
#     'Expedia.com',
#     'Hotels.com',
#     'Official website']},
#   {'id': 190823,
#    'name': 'Hotel Colón',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d190823-Reviews-Hotel_Colon-Barcelona_Catalonia.html',
#    'reviews': 3042,
#    'rating': 4.5,
#    'price_range_usd': {'min': 255, 'max': 407},
#    'phone': '+34 933 01 14 04',
#    'address': 'Avienida Catedral, 7, 08002 Barcelona Spain',
#    'detailed_address': {'street': 'Avienida Catedral, 7',
#     'city': 'Barcelona',
#     'postal_code': '08002',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 133, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.384956,
#    'longitude': 2.175845,
#    'amenities': ['Free Wifi', 'Restaurant', 'Room service', 'Bar/Lounge'],
#    'providers': ['Hotels.com',
#     'Expedia.com',
#     'Booking.com',
#     'Official website']},
#   {'id': 543153,
#    'name': 'Casa Camper Hotel Barcelona',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d543153-Reviews-Casa_Camper_Hotel_Barcelona-Barcelona_Catalonia.html',
#    'reviews': 2632,
#    'rating': 5,
#    'price_range_usd': {'min': 233, 'max': 404},
#    'phone': '+34 933 42 62 80',
#    'address': 'Carrer Elisabets, 11, 08001 Barcelona Spain',
#    'detailed_address': {'street': 'Carrer Elisabets, 11',
#     'city': 'Barcelona',
#     'postal_code': '08001',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 1, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.383293,
#    'longitude': 2.168481,
#    'amenities': ['Free Wifi', 'Bar/Lounge', 'Fitness center'],
#    'providers': ['Hotels.com', 'Expedia.com', 'Booking.com', 'eDreams']},
#   {'id': 1948832,
#    'name': 'Casa Gracia',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d1948832-Reviews-Casa_Gracia-Barcelona_Catalonia.html',
#    'reviews': 1937,
#    'rating': 4,
#    'price_range_usd': {'min': 119, 'max': 223},
#    'phone': '+34 931 74 05 28',
#    'address': 'Passeig de Gracia 116, 08008 Barcelona Spain',
#    'detailed_address': {'street': 'Passeig de Gracia 116',
#     'city': 'Barcelona',
#     'postal_code': '08008',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 95, 'total': 863},
#    'featured_image': None,
#    'latitude': 41.397175,
#    'longitude': 2.159252,
#    'amenities': ['Free Wifi', 'Airport transportation', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'Expedia.com', 'Hotels.com', 'Vio.com']},
#   {'id': 506158,
#    'name': 'Hotel 1898',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d506158-Reviews-Hotel_1898-Barcelona_Catalonia.html',
#    'reviews': 6765,
#    'rating': 4.5,
#    'price_range_usd': {'min': 210, 'max': 425},
#    'phone': '+34 935 52 95 52',
#    'address': 'La Rambla, 109, 08001 Barcelona Spain',
#    'detailed_address': {'street': 'La Rambla, 109',
#     'city': 'Barcelona',
#     'postal_code': '08001',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 28, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.383476,
#    'longitude': 2.171058,
#    'amenities': ['Free Wifi',
#     'Pool',
#     'Heated pool',
#     'Indoor pool',
#     'Outdoor pool'],
#    'providers': ['Expedia.com', 'Booking.com', 'Hotels.com', 'Algotels']},
#   {'id': 228507,
#    'name': 'Barceló Sants',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d228507-Reviews-Barcelo_Sants-Barcelona_Catalonia.html',
#    'reviews': 5798,
#    'rating': 4.5,
#    'price_range_usd': {'min': 130, 'max': 232},
#    'phone': '+34 935 03 53 00',
#    'address': 'Plaza dels Paisos Catalans, S/N, 8014 Barcelona Spain',
#    'detailed_address': {'street': 'Plaza dels Paisos Catalans, S/N',
#     'city': 'Barcelona',
#     'postal_code': '8014',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 113, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.37913,
#    'longitude': 2.139601,
#    'amenities': ['Free Wifi',
#     'Restaurant',
#     'Room service',
#     'Bar/Lounge',
#     'Fitness center'],
#    'providers': ['Expedia.com',
#     'Booking.com',
#     'Barcelo.com',
#     'ZenHotels.com']},
#   {'id': 228464,
#    'name': 'Hotel Alimara Barcelona',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d228464-Reviews-Hotel_Alimara_Barcelona-Barcelona_Catalonia.html',
#    'reviews': 1163,
#    'rating': 4,
#    'price_range_usd': {'min': 107, 'max': 180},
#    'phone': '+34 934 27 00 00',
#    'address': 'Carrer de Berruguete, 126, 08035 Barcelona Spain',
#    'detailed_address': {'street': 'Carrer de Berruguete, 126',
#     'city': 'Barcelona',
#     'postal_code': '08035',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 268, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.434025,
#    'longitude': 2.147445,
#    'amenities': ['Free Wifi',
#     'Restaurant',
#     'Room service',
#     'Bar/Lounge',
#     'Fitness center'],
#    'providers': ['Expedia.com',
#     'Hotels.com',
#     'Official website',
#     'ZenHotels.com']},
#   {'id': 2663628,
#    'name': 'Can Seuba',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d2663628-Reviews-Can_Seuba-Barcelona_Catalonia.html',
#    'reviews': 17,
#    'rating': 4,
#    'price_range_usd': {'min': 55, 'max': 87},
#    'phone': '+34 938 34 59 81',
#    'address': 'C/ Emili Riera 48 Rellinars, 08299 Barcelona Spain',
#    'detailed_address': {'street': 'C/ Emili Riera 48, Rellinars',
#     'city': 'Barcelona',
#     'postal_code': '08299',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 169, 'total': 309},
#    'featured_image': None,
#    'latitude': 41.63994,
#    'longitude': 1.9126,
#    'amenities': ['Free Wifi', 'Pets Allowed', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'Agoda.com']},
#   {'id': 208210,
#    'name': 'Torre Melina Gran Meliá',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d208210-Reviews-Torre_Melina_Gran_Melia-Barcelona_Catalonia.html',
#    'reviews': 46,
#    'rating': 4,
#    'price_range_usd': {'min': 234, 'max': 373},
#    'phone': '+34 933 64 40 40',
#    'address': 'Av. Diagonal, 671, 08028 Barcelona Spain',
#    'detailed_address': {'street': 'Av. Diagonal, 671',
#     'city': 'Barcelona',
#     'postal_code': '08028',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 383, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.381443,
#    'longitude': 2.108862,
#    'amenities': ['Free Wifi',
#     'Pool',
#     'Outdoor pool',
#     'Restaurant',
#     'Room service'],
#    'providers': ['Melia.com', 'Expedia.com', 'Booking.com', 'Hotels.com']},
#   {'id': 231518,
#    'name': 'Ibis Barcelona Meridiana',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d231518-Reviews-Ibis_Barcelona_Meridiana-Barcelona_Catalonia.html',
#    'reviews': 1478,
#    'rating': 4,
#    'price_range_usd': {'min': 91, 'max': 153},
#    'phone': '+34 932 76 83 10',
#    'address': 'Paseo Andreu Nin 9, 08016 Barcelona Spain',
#    'detailed_address': {'street': 'Paseo Andreu Nin 9',
#     'city': 'Barcelona',
#     'postal_code': '08016',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 276, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.435486,
#    'longitude': 2.181594,
#    'amenities': ['Free Wifi', 'Restaurant', 'Bar/Lounge'],
#    'providers': ['Expedia.com', 'Hotels.com', 'Booking.com', 'Vio.com']},
#   {'id': 10670124,
#    'name': 'ibis Styles Barcelona City Bogatell',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d10670124-Reviews-Ibis_Styles_Barcelona_City_Bogatell-Barcelona_Catalonia.html',
#    'reviews': 1119,
#    'rating': 4.5,
#    'price_range_usd': {'min': 131, 'max': 228},
#    'phone': '+34 934 83 37 48',
#    'address': 'Carrer de Llull 71 HB004742, 08005 Barcelona Spain',
#    'detailed_address': {'street': 'Carrer de Llull 71, HB004742',
#     'city': 'Barcelona',
#     'postal_code': '08005',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 146, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.394768,
#    'longitude': 2.193382,
#    'amenities': ['Free Wifi',
#     'Breakfast included',
#     'Pool',
#     'Outdoor pool',
#     'Bar/Lounge'],
#    'providers': ['Expedia.com', 'Hotels.com', 'Booking.com', 'ibis Styles']},
#   {'id': 228592,
#    'name': 'Apartamentos Hesperia Barcelona Sant Joan',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d228592-Reviews-Apartamentos_Hesperia_Barcelona_Sant_Joan-Barcelona_Catalonia.html',
#    'reviews': 1046,
#    'rating': 4,
#    'price_range_usd': {'min': 91, 'max': 135},
#    'phone': '+34 934 77 30 03',
#    'address': 'Calle Josep Trueta 2, 08970 Barcelona Spain',
#    'detailed_address': {'street': 'Calle Josep Trueta 2',
#     'city': 'Barcelona',
#     'postal_code': '08970',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 313, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.3734,
#    'longitude': 2.07078,
#    'amenities': ['Free Wifi',
#     'Pool',
#     'Outdoor pool',
#     'Restaurant',
#     'Room service'],
#    'providers': ['Booking.com',
#     'Expedia.com',
#     'Hotels.com',
#     'Skyscanner.com']},
#   {'id': 231502,
#    'name': 'INNSiDE by Meliá Barcelona Apolo',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d231502-Reviews-INNSiDE_by_Melia_Barcelona_Apolo-Barcelona_Catalonia.html',
#    'reviews': 142,
#    'rating': 4.5,
#    'price_range_usd': {'min': 176, 'max': 332},
#    'phone': '+34 933 43 30 00',
#    'address': 'Avenida del Paralelo 57-59, 08004 Barcelona Spain',
#    'detailed_address': {'street': 'Avenida del Paralelo 57-59',
#     'city': 'Barcelona',
#     'postal_code': '08004',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 132, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.374752,
#    'longitude': 2.170721,
#    'amenities': ['Free Wifi',
#     'Restaurant',
#     'Room service',
#     'Pets Allowed',
#     'Bar/Lounge'],
#    'providers': ['Melia.com', 'Expedia.com', 'Booking.com', 'Skyscanner.com']},
#   {'id': 601350,
#    'name': 'Travelodge Barcelona Fira',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d601350-Reviews-Travelodge_Barcelona_Fira-Barcelona_Catalonia.html',
#    'reviews': 424,
#    'rating': 4,
#    'price_range_usd': {'min': 80, 'max': 177},
#    'phone': '+34 932 63 72 50',
#    'address': "Carrer de la Botànica, 25 L'Hospitalet, 08908 Barcelona Spain",
#    'detailed_address': {'street': "Carrer de la Botànica, 25, L'Hospitalet",
#     'city': 'Barcelona',
#     'postal_code': '08908',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 270, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.352493,
#    'longitude': 2.1334,
#    'amenities': ['Restaurant', 'Bar/Lounge'],
#    'providers': ['Booking.com',
#     'Expedia.com',
#     'Hotels.com',
#     'Skyscanner.com']},
#   {'id': 231502,
#    'name': 'INNSiDE by Meliá Barcelona Apolo',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d231502-Reviews-INNSiDE_by_Melia_Barcelona_Apolo-Barcelona_Catalonia.html',
#    'reviews': 142,
#    'rating': 4.5,
#    'price_range_usd': {'min': 176, 'max': 332},
#    'phone': '+34 933 43 30 00',
#    'address': 'Avenida del Paralelo 57-59, 08004 Barcelona Spain',
#    'detailed_address': {'street': 'Avenida del Paralelo 57-59',
#     'city': 'Barcelona',
#     'postal_code': '08004',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 132, 'total': 512},
#    'featured_image': None,
#    'latitude': 41.374752,
#    'longitude': 2.170721,
#    'amenities': ['Free Wifi',
#     'Restaurant',
#     'Room service',
#     'Pets Allowed',
#     'Bar/Lounge'],
#    'providers': ['Melia.com']}]}

# %%
url = "https://tripadvisor-scraper.p.rapidapi.com/hotels/list"

querystring = {"query":"Santiago de Compostela", "limit":"50", "adults": "2"}

headers = {
	"x-rapidapi-key": key,
	"x-rapidapi-host": "tripadvisor-scraper.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

respuesta2=response.json()

# %%
respuesta2
# Out:
# {'link': 'https://www.tripadvisor.com/Hotels-g187508-Santiago_de_Compostela_Province_of_A_Coruna_Galicia-Hotels.html',
#  'total_pages': 11,
#  'current_page': 1,
#  'total_items_count': 307,
#  'items_count': 34,
#  'results': [{'id': 1510515,
#    'name': 'Hotel Spa Relais & Chateaux A Quinta da Auga',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1510515-Reviews-Hotel_Spa_Relais_Chateaux_A_Quinta_da_Auga-Santiago_de_Compostela_Province_of_A_Coruna.html',
#    'reviews': 1116,
#    'rating': 4.5,
#    'price_range_usd': {'min': 207, 'max': 297},
#    'phone': '+34 981 53 46 36',
#    'address': 'Paseo Amaia 23B Urbanización Brandia. Vidán, 15706, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Paseo Amaia 23B, Urbanización Brandia. Vidán',
#     'city': None,
#     'postal_code': '15706',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 8, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.870335,
#    'longitude': -8.582583,
#    'amenities': ['Free Wifi',
#     'Free parking',
#     'Breakfast included',
#     'Heated pool',
#     'Indoor pool'],
#    'providers': ['Expedia.com', 'Booking.com', 'Hotels.com', 'ZenHotels.com']},
#   {'id': 584984,
#    'name': 'NH Collection Santiago de Compostela',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d584984-Reviews-NH_Collection_Santiago_de_Compostela-Santiago_de_Compostela_Province_of_A_Coruna_Galici.html',
#    'reviews': 2316,
#    'rating': 4.5,
#    'price_range_usd': {'min': 97, 'max': 177},
#    'phone': '+34 981 55 80 70',
#    'address': 'Avenida Burgo das Nacions s/n Campus Norte, 15705, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Avenida Burgo das Nacions s/n, Campus Norte',
#     'city': None,
#     'postal_code': '15705',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 19, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.889473,
#    'longitude': -8.543447,
#    'amenities': ['Free Wifi',
#     'Free parking',
#     'Pool',
#     'Heated pool',
#     'Indoor pool'],
#    'providers': ['Algotels', 'Vio.com', 'Destinia.com', 'StayForLong']},
#   {'id': 248531,
#    'name': 'Hotel Compostela',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d248531-Reviews-Hotel_Compostela-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 764,
#    'rating': 4,
#    'price_range_usd': {'min': 71, 'max': 177},
#    'phone': '+34 981 58 57 00',
#    'address': 'Rua Hórreo, 1, 15702, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua Hórreo, 1',
#     'city': None,
#     'postal_code': '15702',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 25, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.876884,
#    'longitude': -8.54388,
#    'amenities': ['Free Wifi', 'Room service', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'Expedia.com', 'Hotels.com', 'Lol.travel']},
#   {'id': 1836140,
#    'name': 'Hotel Restaurante Asador De Roxos Casa Albardonedo',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g1870402-d1836140-Reviews-Hotel_Restaurante_Asador_De_Roxos_Casa_Albardonedo-Roxos_Santiago_de_Compostela_Provi.html',
#    'reviews': 233,
#    'rating': 4.5,
#    'price_range_usd': {'min': 88, 'max': 94},
#    'phone': '+34 666 57 68 05',
#    'address': 'Carretera de Muros 112, 15896 Roxos, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Carretera de Muros 112',
#     'city': 'Roxos',
#     'postal_code': '15896',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 13, 'total': 95},
#    'featured_image': None,
#    'latitude': 42.876472,
#    'longitude': -8.610071,
#    'amenities': ['Free Wifi',
#     'Free parking',
#     'Breakfast included',
#     'Restaurant',
#     'Pets Allowed'],
#    'providers': ['Booking.com',
#     'Expedia.com',
#     'Hotels.com',
#     'Skyscanner.com']},
#   {'id': 231702,
#    'name': 'Gran Hotel Los Abetos',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d231702-Reviews-Gran_Hotel_Los_Abetos-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 808,
#    'rating': 4.5,
#    'price_range_usd': {'min': 91, 'max': 180},
#    'phone': '+34 981 55 70 26',
#    'address': 'Calle San Lazaro, S/N, 15820, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Calle San Lazaro, S/N',
#     'city': None,
#     'postal_code': '15820',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 18, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.884766,
#    'longitude': -8.505159,
#    'amenities': ['Free Wifi',
#     'Free parking',
#     'Outdoor pool',
#     'Restaurant',
#     'Room service'],
#    'providers': ['Booking.com', 'Expedia.com', 'Hotels.com', 'Lol.travel']},
#   {'id': 25075247,
#    'name': 'Hotel Plaza Obradoiro',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d25075247-Reviews-Hotel_Plaza_Obradoiro-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 17,
#    'rating': 4.5,
#    'price_range_usd': {'min': 79, 'max': 244},
#    'phone': '+34 981 07 31 48',
#    'address': 'Avenida De Raxoi, 1, 15705, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Avenida De Raxoi, 1',
#     'city': None,
#     'postal_code': '15705',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 29, 'total': 95},
#    'featured_image': None,
#    'latitude': 42.880028,
#    'longitude': -8.545759,
#    'amenities': ['Free Wifi'],
#    'providers': ['Booking.com']},
#   {'id': 578149,
#    'name': 'Casa Grande do Bachao',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d578149-Reviews-Casa_Grande_do_Bachao-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 431,
#    'rating': 5,
#    'price_range_usd': {'min': 113, 'max': 128},
#    'phone': '+34 981 55 87 05',
#    'address': 'Monte Bachao Santa Cristina de Fecha, 15898, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Monte Bachao Santa Cristina de Fecha',
#     'city': None,
#     'postal_code': '15898',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 2, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.974483,
#    'longitude': -8.588368,
#    'amenities': ['Free parking',
#     'Pool',
#     'Outdoor pool',
#     'Restaurant',
#     'Pets Allowed'],
#    'providers': ['Booking.com', 'Priceline', 'eDreams', 'Agoda.com']},
#   {'id': 17644326,
#    'name': 'Monte do Gozo',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d17644326-Reviews-Monte_do_Gozo-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 11,
#    'rating': 3.5,
#    'price_range_usd': {'min': 43, 'max': 59},
#    'phone': '+34 881 25 53 86',
#    'address': 'Rua do Gozo 18, 15820, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua do Gozo 18',
#     'city': None,
#     'postal_code': '15820',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 61, 'total': 96},
#    'featured_image': None,
#    'latitude': 42.886337,
#    'longitude': -8.501068,
#    'amenities': ['Free Wifi',
#     'Free parking',
#     'Pool',
#     'Restaurant',
#     'Bar/Lounge'],
#    'providers': ['Booking.com', 'Expedia.com', 'Trip.com', 'Lol.travel']},
#   {'id': 10090105,
#    'name': 'La  Credencial',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d10090105-Reviews-La_Credencial-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 43,
#    'rating': 4.5,
#    'price_range_usd': {'min': 24, 'max': 40},
#    'phone': '+34 981 06 80 83',
#    'address': 'Rua Fonte dos Concheiros 13 Albuergue Turistico de Peregrinos, 15703, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua Fonte dos Concheiros 13, Albuergue Turistico de Peregrinos',
#     'city': None,
#     'postal_code': '15703',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 10, 'total': 96},
#    'featured_image': None,
#    'latitude': 42.88518,
#    'longitude': -8.53177,
#    'amenities': ['Free Wifi'],
#    'providers': ['Official Hotel Site',
#     'StayForLong',
#     'Booking.com',
#     'Expedia.com']},
#   {'id': 228528,
#    'name': 'Hotel Santiago Apostol',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d228528-Reviews-Hotel_Santiago_Apostol-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 338,
#    'rating': 3.5,
#    'price_range_usd': {'min': 55, 'max': 103},
#    'phone': '+34 699 32 09 62',
#    'address': 'Cuesta San Marcos 1 Outer City, 15890, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Cuesta San Marcos 1, Outer City',
#     'city': None,
#     'postal_code': '15890',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 54, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.889236,
#    'longitude': -8.502356,
#    'amenities': ['Free Wifi', 'Free parking', 'Restaurant', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'Trip.com', 'Algotels', 'Vio.com']},
#   {'id': 482510,
#    'name': 'Eurostars San Lazaro',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d482510-Reviews-Eurostars_San_Lazaro-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 555,
#    'rating': 4,
#    'price_range_usd': {'min': 62, 'max': 140},
#    'phone': '+34 981 55 10 00',
#    'address': 'Avenida Fernando de Casas Novoa S/N, 15703, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Avenida Fernando de Casas Novoa S/N',
#     'city': None,
#     'postal_code': '15703',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 23, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.883247,
#    'longitude': -8.512763,
#    'amenities': ['Free Wifi',
#     'Free parking',
#     'Restaurant',
#     'Room service',
#     'Pets Allowed'],
#    'providers': ['Expedia.com', 'Booking.com', 'Hotels.com', 'Lol.travel']},
#   {'id': 583203,
#    'name': 'Hotel Altaïr',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d583203-Reviews-Hotel_Altair-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 608,
#    'rating': 4.5,
#    'price_range_usd': {'min': 81, 'max': 163},
#    'phone': '+34 981 55 47 12',
#    'address': 'Rúa dos Loureiros 12, 15704, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rúa dos Loureiros 12',
#     'city': None,
#     'postal_code': '15704',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 3, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.88388,
#    'longitude': -8.54269,
#    'amenities': ['Free Wifi', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'Expedia.com', 'Hotels.com', 'Vio.com']},
#   {'id': 24121482,
#    'name': 'Exe Peregrino',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d24121482-Reviews-Exe_Peregrino-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 38,
#    'rating': 4,
#    'price_range_usd': {'min': 65, 'max': 142},
#    'phone': '+34 981 79 52 99',
#    'address': 'Av. De Rosalía De Castro, S/N, 15706, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Av. De Rosalía De Castro, S/N',
#     'city': None,
#     'postal_code': '15706',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 53, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.8716,
#    'longitude': -8.55544,
#    'amenities': ['Free Wifi', 'Pool', 'Restaurant'],
#    'providers': ['ZenHotels.com', 'Booking.com', 'Expedia.com', 'Hotels.com']},
#   {'id': 483859,
#    'name': 'Hotel Rua Villar',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d483859-Reviews-Hotel_Rua_Villar-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 315,
#    'rating': 4.5,
#    'price_range_usd': {'min': 76, 'max': 168},
#    'phone': '+34 981 51 98 58',
#    'address': 'Rua Vilar 8-10, 15705, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua Vilar 8-10',
#     'city': None,
#     'postal_code': '15705',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 5, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.879616,
#    'longitude': -8.544286,
#    'amenities': ['Free Wifi', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'eDreams', 'Skyscanner.com', 'Priceline']},
#   {'id': 234585,
#    'name': 'Hotel Oca Puerta del Camino',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d234585-Reviews-Hotel_Oca_Puerta_del_Camino-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 649,
#    'rating': 4,
#    'price_range_usd': {'min': 62, 'max': 141},
#    'phone': '+34 981 56 94 00',
#    'address': 'Rua Miguel Ferro Caaveiro s/n, 15707, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua Miguel Ferro Caaveiro s/n',
#     'city': None,
#     'postal_code': '15707',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 16, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.884068,
#    'longitude': -8.513224,
#    'amenities': ['Free Wifi',
#     'Pool',
#     'Outdoor pool',
#     'Restaurant',
#     'Airport transportation'],
#    'providers': ['Booking.com', 'Expedia.com', 'Hotels.com', 'ZenHotels.com']},
#   {'id': 234587,
#    'name': 'Hotel Santiago Plaza Affiliated by Melia',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d234587-Reviews-Hotel_Santiago_Plaza_Affiliated_by_Melia-Santiago_de_Compostela_Province_of_A_Coruna_Ga.html',
#    'reviews': 940,
#    'rating': 4,
#    'price_range_usd': {'min': 68, 'max': 168},
#    'phone': '+34 981 53 49 49',
#    'address': 'C/ Restollal, 24, 15702, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'C/ Restollal, 24',
#     'city': None,
#     'postal_code': '15702',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 27, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.86489,
#    'longitude': -8.54356,
#    'amenities': ['Free Wifi', 'Restaurant', 'Room service', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'Expedia.com', 'Melia.com', 'Algotels']},
#   {'id': 3472761,
#    'name': 'Hotel Montes',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d3472761-Reviews-Hotel_Montes-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 4,
#    'rating': 4.5,
#    'price_range_usd': {'min': 82, 'max': 194},
#    'phone': '+34 654 41 05 46',
#    'address': 'Rua Raina 11, 15704, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua Raina 11',
#     'city': None,
#     'postal_code': '15704',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 64, 'total': 95},
#    'featured_image': None,
#    'latitude': 42.879517,
#    'longitude': -8.544786,
#    'amenities': ['Free Wifi', 'Airport transportation', 'Bar/Lounge'],
#    'providers': ['Booking.com']},
#   {'id': 244677,
#    'name': 'Hotel Alda San Carlos',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d244677-Reviews-Hotel_Alda_San_Carlos-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 256,
#    'rating': 4,
#    'price_range_usd': {'min': 52, 'max': 156},
#    'phone': '+34 881 09 29 83',
#    'address': 'C/ Hórreo 106, 15702, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'C/ Hórreo 106',
#     'city': None,
#     'postal_code': '15702',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 35, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.872707,
#    'longitude': -8.544815,
#    'amenities': ['Free Wifi', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'eDreams', 'Priceline', 'Lol.travel']},
#   {'id': 1389231,
#    'name': 'Hotel San Lazaro',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1389231-Reviews-Hotel_San_Lazaro-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 181,
#    'rating': 4,
#    'price_range_usd': {'min': 55, 'max': 91},
#    'phone': '+34 981 58 43 44',
#    'address': 'Rua Valino 1, 15707, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua Valino 1',
#     'city': None,
#     'postal_code': '15707',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 27, 'total': 95},
#    'featured_image': None,
#    'latitude': 42.88705,
#    'longitude': -8.52606,
#    'amenities': ['Free Wifi', 'Restaurant', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'Skyscanner.com', 'Priceline', 'eDreams']},
#   {'id': 1160876,
#    'name': 'Hotel Bonaval',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1160876-Reviews-Hotel_Bonaval-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 289,
#    'rating': 4.5,
#    'price_range_usd': {'min': 48, 'max': 135},
#    'phone': '+34 981 55 88 83',
#    'address': 'Rua Bonaval 2, 15703, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua Bonaval 2',
#     'city': None,
#     'postal_code': '15703',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 28, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.881817,
#    'longitude': -8.538572,
#    'amenities': ['Free Wifi', 'Breakfast included', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'eDreams', 'ZenHotels.com', 'Agoda.com']},
#   {'id': 501752,
#    'name': 'Eurostars Gran Hotel Santiago',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d501752-Reviews-Eurostars_Gran_Hotel_Santiago-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 559,
#    'rating': 4,
#    'price_range_usd': {'min': 68, 'max': 156},
#    'phone': '+34 981 53 42 22',
#    'address': 'Avenida Mestre Mateo 27, 15706, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Avenida Mestre Mateo 27',
#     'city': None,
#     'postal_code': '15706',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 31, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.872524,
#    'longitude': -8.557373,
#    'amenities': ['Restaurant', 'Room service', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'Expedia.com', 'Hotels.com', 'Lol.travel']},
#   {'id': 1389234,
#    'name': 'Hotel Windsor',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1389234-Reviews-Hotel_Windsor-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 200,
#    'rating': 4,
#    'price_range_usd': {'min': 47, 'max': 80},
#    'phone': '+34 981 59 29 39',
#    'address': 'Rua da Republica de El Salvador 16, 15701, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua da Republica de El Salvador 16',
#     'city': None,
#     'postal_code': '15701',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 47, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.87459,
#    'longitude': -8.546947,
#    'amenities': ['Free Wifi', 'Bar/Lounge'],
#    'providers': ['Skyscanner.com',
#     'StayForLong',
#     'Booking.com',
#     'Expedia.com']},
#   {'id': 25075247,
#    'name': 'Hotel Plaza Obradoiro',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d25075247-Reviews-Hotel_Plaza_Obradoiro-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 17,
#    'rating': 4.5,
#    'price_range_usd': {'min': 79, 'max': 244},
#    'phone': '+34 981 07 31 48',
#    'address': 'Avenida De Raxoi, 1, 15705, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Avenida De Raxoi, 1',
#     'city': None,
#     'postal_code': '15705',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 29, 'total': 95},
#    'featured_image': None,
#    'latitude': 42.880028,
#    'longitude': -8.545759,
#    'amenities': ['Free Wifi'],
#    'providers': ['Booking.com', 'Expedia.com', 'Hotels.com', 'Priceline']},
#   {'id': 1389246,
#    'name': 'Hotel Restaurante San Paio',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1389246-Reviews-Hotel_Restaurante_San_Paio-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 65,
#    'rating': 3,
#    'price_range_usd': {'min': 65, 'max': 69},
#    'phone': '+34 981 88 82 21',
#    'address': 'Carretera Santiago-Aeropuerto. Lavacolla, 15820, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Carretera Santiago-Aeropuerto. Lavacolla',
#     'city': None,
#     'postal_code': '15820',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 66, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.900467,
#    'longitude': -8.447872,
#    'amenities': ['Restaurant', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'Agoda.com']},
#   {'id': 1389221,
#    'name': 'Moure Hotel',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1389221-Reviews-Moure_Hotel-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 368,
#    'rating': 4.5,
#    'price_range_usd': {'min': 81, 'max': 171},
#    'phone': '+34 981 58 36 37',
#    'address': 'Rua Loureiros 6, 15704, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua Loureiros 6',
#     'city': None,
#     'postal_code': '15704',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 6, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.88366,
#    'longitude': -8.542847,
#    'amenities': ['Free Wifi', 'Breakfast included', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'Expedia.com', 'Hotels.com', 'Vio.com']},
#   {'id': 1983523,
#    'name': 'Hotel Carris Casa de la Troya',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1983523-Reviews-Hotel_Carris_Casa_de_la_Troya-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 452,
#    'rating': 4.5,
#    'price_range_usd': {'min': 76, 'max': 204},
#    'phone': '+34 981 55 58 79',
#    'address': 'Rua da Acibecheria 14, 15704, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua da Acibecheria 14',
#     'city': None,
#     'postal_code': '15704',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 11, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.881294,
#    'longitude': -8.543447,
#    'amenities': ['Free Wifi', 'Room service', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'Expedia.com', 'Hotels.com', 'Lol.travel']},
#   {'id': 577883,
#    'name': 'Hotel Castro',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d577883-Reviews-Hotel_Castro-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 107,
#    'rating': 3.5,
#    'price_range_usd': {'min': 50, 'max': 78},
#    'phone': '+34 981 50 93 04',
#    'address': 'Rua Formaris 22-23, 15884, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua Formaris 22-23',
#     'city': None,
#     'postal_code': '15884',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 57, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.9192,
#    'longitude': -8.495146,
#    'amenities': ['Free Wifi', 'Free parking', 'Restaurant', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'Priceline', 'Trip.com', 'Lol.travel']},
#   {'id': 1389221,
#    'name': 'Moure Hotel',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1389221-Reviews-Moure_Hotel-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 368,
#    'rating': 4.5,
#    'price_range_usd': {'min': 81, 'max': 171},
#    'phone': '+34 981 58 36 37',
#    'address': 'Rua Loureiros 6, 15704, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua Loureiros 6',
#     'city': None,
#     'postal_code': '15704',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 6, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.88366,
#    'longitude': -8.542847,
#    'amenities': ['Free Wifi', 'Breakfast included', 'Bar/Lounge'],
#    'providers': ['Booking.com']},
#   {'id': 232804,
#    'name': 'Hotel Congreso',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d232804-Reviews-Hotel_Congreso-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 922,
#    'rating': 3.5,
#    'price_range_usd': {'min': 58, 'max': 75},
#    'phone': '+34 981 81 90 80',
#    'address': 'Rua das Mamoas de Montouto, 4, 15886, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua das Mamoas de Montouto, 4',
#     'city': None,
#     'postal_code': '15886',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 45, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.836082,
#    'longitude': -8.546526,
#    'amenities': ['Free Wifi',
#     'Free parking',
#     'Pool',
#     'Outdoor pool',
#     'Restaurant'],
#    'providers': ['Booking.com', 'Expedia.com', 'Hotels.com', 'Lol.travel']},
#   {'id': 5865931,
#    'name': 'Smart Boutique Hotel Literario San Bieito',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d5865931-Reviews-Smart_Boutique_Hotel_Literario_San_Bieito-Santiago_de_Compostela_Province_of_A_Coruna_.html',
#    'reviews': 345,
#    'rating': 4.5,
#    'price_range_usd': {'min': 60, 'max': 173},
#    'phone': '+34 981 55 88 83',
#    'address': 'Rua San Bieito 1, 15704, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua San Bieito 1',
#     'city': None,
#     'postal_code': '15704',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 12, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.88102,
#    'longitude': -8.54158,
#    'amenities': ['Free Wifi', 'Breakfast included', 'Bar/Lounge'],
#    'providers': ['Booking.com', 'eDreams', 'StayForLong', 'Agoda.com']},
#   {'id': 238611,
#    'name': 'Hotel Universal',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d238611-Reviews-Hotel_Universal-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 541,
#    'rating': 3.5,
#    'price_range_usd': {'min': 50, 'max': 100},
#    'phone': '+34 981 58 58 00',
#    'address': 'Plaza de Galicia 2, 15702, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Plaza de Galicia 2',
#     'city': None,
#     'postal_code': '15702',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 40, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.87641,
#    'longitude': -8.544474,
#    'amenities': ['Free Wifi'],
#    'providers': ['Booking.com', 'Trip.com', 'Priceline', 'Lol.travel']},
#   {'id': 238654,
#    'name': 'Hotel Exe Area Central',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d238654-Reviews-Hotel_Exe_Area_Central-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 354,
#    'rating': 3.5,
#    'price_range_usd': {'min': 58, 'max': 141},
#    'phone': '+34 981 55 22 22',
#    'address': 'Rua Paris 7C Centro Comercial Area Central, 15707, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rua Paris 7C, Centro Comercial Area Central',
#     'city': None,
#     'postal_code': '15707',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 43, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.882317,
#    'longitude': -8.526722,
#    'amenities': ['Free Wifi'],
#    'providers': ['Booking.com', 'Trip.com', 'Algotels', 'Lol.travel']},
#   {'id': 10265761,
#    'name': 'Apartamentos Cancelas By Bossh Hotels',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d10265761-Reviews-Apartamentos_Cancelas_By_Bossh_Hotels-Santiago_de_Compostela_Province_of_A_Coruna_Gal.html',
#    'reviews': 30,
#    'rating': 3,
#    'price_range_usd': {'min': 49, 'max': 91},
#    'phone': '+34 600 42 72 96',
#    'address': 'Rúa dos Salgueiriños de Abaixo, 28, 15703, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rúa dos Salgueiriños de Abaixo, 28',
#     'city': None,
#     'postal_code': '15703',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 69, 'total': 96},
#    'featured_image': None,
#    'latitude': 42.893932,
#    'longitude': -8.530273,
#    'amenities': ['Free Wifi', 'Free parking'],
#    'providers': ['Booking.com', 'Expedia.com', 'Hotels.com', 'Priceline']},
#   {'id': 583203,
#    'name': 'Hotel Altaïr',
#    'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d583203-Reviews-Hotel_Altair-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html',
#    'reviews': 608,
#    'rating': 4.5,
#    'price_range_usd': {'min': 81, 'max': 163},
#    'phone': '+34 981 55 47 12',
#    'address': 'Rúa dos Loureiros 12, 15704, Santiago de Compostela Spain',
#    'detailed_address': {'street': 'Rúa dos Loureiros 12',
#     'city': None,
#     'postal_code': '15704',
#     'state': None,
#     'country': 'Spain'},
#    'ranking': {'current_rank': 3, 'total': 69},
#    'featured_image': None,
#    'latitude': 42.88388,
#    'longitude': -8.54269,
#    'amenities': ['Free Wifi', 'Bar/Lounge'],
#    'providers': ['Booking.com']}]}

# %%
with open('hoteleles_santiago.json', 'w') as archivo:
    json.dump(respuesta2, archivo, indent=4)

# %%
def extraer_informacion_hoteles(respuesta_json):
    """
    Extrae información relevante sobre hoteles a partir de una respuesta JSON de un servicio de búsqueda de hoteles.

    La función itera sobre los resultados del JSON y extrae información clave sobre cada hotel, 
    incluyendo el nombre, número de reseñas, rating, rango de precios, ciudad, servicios ofrecidos y un enlace al hotel.
    Calcula además el precio medio por noche basado en el rango de precios.

    Args:
        respuesta_json (dict): Un diccionario que representa la respuesta en formato JSON de un servicio de búsqueda de hoteles.

    Returns:
        list[dict]: Una lista de diccionarios, donde cada diccionario contiene la información de un hotel con las siguientes claves:
            - nombre: El nombre del hotel.
            - numero_reviews: Número de reseñas del hotel.
            - rating: Rating del hotel.
            - precio_rango_min: El precio mínimo por noche en USD.
            - precio_rango_max: El precio máximo por noche en USD.
            - precio_medio_por noche: Precio medio por noche calculado a partir del rango de precios.
            - ciudad: Ciudad donde se encuentra el hotel.
            - servicios: Lista de servicios que ofrece el hotel.
            - link: URL que enlaza a la página del hotel.
    """
    lista_diccionarios = []
    res = respuesta_json
    for i in range(0, len(res.get("results", []))):

        nombre = res["results"][i].get("name", "N/A")
        numero_reviews = res["results"][i].get("reviews", 0)
        rating = res["results"][i].get("rating", "N/A")
        
        rango_precios = res["results"][i].get("price_range_usd", {})
        precio_rango_min = rango_precios.get("min", 0)
        precio_rango_max = rango_precios.get("max", 0)
        precio_medio = (precio_rango_max + precio_rango_min) / 2 if (precio_rango_max + precio_rango_min) > 0 else 0
        
        ciudad = res["results"][i].get("detailed_address", {}).get("city", "N/A")
        servicios = res["results"][i].get("amenities", [])
        link = res["results"][i].get("link", "N/A")

        diccionario_hotel= {"nombre":nombre,
                "numero_reviews":numero_reviews,
                "rating": rating,
                "precio_rango_min":precio_rango_min,
                "precio_rango_max":precio_rango_max,
                "precio_medio_por noche":precio_medio,
                "ciudad":ciudad,
                "servicios":servicios,
                "link":link
                }
        lista_diccionarios.append(diccionario_hotel)
    return lista_diccionarios

# %%
extraer_informacion_hoteles(respuesta)
# Out:
# [{'nombre': 'Andante Hotel',
#   'numero_reviews': 2817,
#   'rating': 4.5,
#   'precio_rango_min': 150,
#   'precio_rango_max': 241,
#   'precio_medio_por noche': 195.5,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi', 'Pool', 'Outdoor pool', 'Fitness center'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d2545026-Reviews-Andante_Hotel-Barcelona_Catalonia.html'},
#  {'nombre': 'Hyatt Regency Barcelona Tower',
#   'numero_reviews': 3566,
#   'rating': 4.5,
#   'precio_rango_min': 187,
#   'precio_rango_max': 295,
#   'precio_medio_por noche': 241.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Pool',
#    'Heated pool',
#    'Indoor pool',
#    'Restaurant'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d630596-Reviews-Hyatt_Regency_Barcelona_Tower-Barcelona_Catalonia.html'},
#  {'nombre': 'Hotel Astoria',
#   'numero_reviews': 1900,
#   'rating': 4.5,
#   'precio_rango_min': 118,
#   'precio_rango_max': 233,
#   'precio_medio_por noche': 175.5,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Pool',
#    'Outdoor pool',
#    'Restaurant',
#    'Room service'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d228590-Reviews-Hotel_Astoria-Barcelona_Catalonia.html'},
#  {'nombre': 'Majestic Hotel & Spa Barcelona',
#   'numero_reviews': 4259,
#   'rating': 4.5,
#   'precio_rango_min': 339,
#   'precio_rango_max': 553,
#   'precio_medio_por noche': 446.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Pool',
#    'Outdoor pool',
#    'Restaurant',
#    'Airport transportation'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d190616-Reviews-Majestic_Hotel_Spa_Barcelona-Barcelona_Catalonia.html'},
#  {'nombre': 'Hotel Catalonia Park Güell',
#   'numero_reviews': 1417,
#   'rating': 3.5,
#   'precio_rango_min': 86,
#   'precio_rango_max': 185,
#   'precio_medio_por noche': 135.5,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Outdoor pool',
#    'Restaurant',
#    'Room service',
#    'Pets Allowed'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d236194-Reviews-Hotel_Catalonia_Park_Guell-Barcelona_Catalonia.html'},
#  {'nombre': 'NH Collection Barcelona Podium',
#   'numero_reviews': 1495,
#   'rating': 4.5,
#   'precio_rango_min': 175,
#   'precio_rango_max': 318,
#   'precio_medio_por noche': 246.5,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Pool',
#    'Outdoor pool',
#    'Restaurant',
#    'Room service'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d206920-Reviews-NH_Collection_Barcelona_Podium-Barcelona_Catalonia.html'},
#  {'nombre': 'Oriente Atiram Hotel',
#   'numero_reviews': 2480,
#   'rating': 4,
#   'precio_rango_min': 136,
#   'precio_rango_max': 240,
#   'precio_medio_por noche': 188.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi', 'Restaurant', 'Room service', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d250390-Reviews-Oriente_Atiram_Hotel-Barcelona_Catalonia.html'},
#  {'nombre': 'Tres Torres Atiram Hotel',
#   'numero_reviews': 581,
#   'rating': 4,
#   'precio_rango_min': 114,
#   'precio_rango_max': 194,
#   'precio_medio_por noche': 154.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi', 'Restaurant', 'Room service', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d231529-Reviews-Tres_Torres_Atiram_Hotel-Barcelona_Catalonia.html'},
#  {'nombre': 'Travelodge Barcelona Poblenou',
#   'numero_reviews': 2625,
#   'rating': 4,
#   'precio_rango_min': 87,
#   'precio_rango_max': 157,
#   'precio_medio_por noche': 122.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Restaurant', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d3533952-Reviews-Travelodge_Barcelona_Poblenou-Barcelona_Catalonia.html'},
#  {'nombre': 'Catalonia Magdalenes',
#   'numero_reviews': 1564,
#   'rating': 5,
#   'precio_rango_min': 196,
#   'precio_rango_max': 360,
#   'precio_medio_por noche': 278.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Pool',
#    'Heated pool',
#    'Outdoor pool',
#    'Restaurant'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d10062222-Reviews-Catalonia_Magdalenes-Barcelona_Catalonia.html'},
#  {'nombre': 'H10 Madison',
#   'numero_reviews': 1289,
#   'rating': 5,
#   'precio_rango_min': 202,
#   'precio_rango_max': 419,
#   'precio_medio_por noche': 310.5,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Pool',
#    'Outdoor pool',
#    'Restaurant',
#    'Room service'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d13223478-Reviews-H10_Madison-Barcelona_Catalonia.html'},
#  {'nombre': 'Seventy Barcelona',
#   'numero_reviews': 1204,
#   'rating': 5,
#   'precio_rango_min': 226,
#   'precio_rango_max': 455,
#   'precio_medio_por noche': 340.5,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Pool',
#    'Indoor pool',
#    'Restaurant',
#    'Room service'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d19092478-Reviews-Seventy_Barcelona-Barcelona_Catalonia.html'},
#  {'nombre': 'Catalonia Barcelona Plaza',
#   'numero_reviews': 3911,
#   'rating': 4,
#   'precio_rango_min': 142,
#   'precio_rango_max': 316,
#   'precio_medio_por noche': 229.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Pool',
#    'Outdoor pool',
#    'Restaurant',
#    'Room service'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d229676-Reviews-Catalonia_Barcelona_Plaza-Barcelona_Catalonia.html'},
#  {'nombre': 'W Barcelona',
#   'numero_reviews': 8294,
#   'rating': 4,
#   'precio_rango_min': 322,
#   'precio_rango_max': 660,
#   'precio_medio_por noche': 491.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Beachfront',
#    'Pool',
#    'Outdoor pool',
#    'Restaurant'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d1465497-Reviews-W_Barcelona-Barcelona_Catalonia.html'},
#  {'nombre': 'Hotel Arc La Rambla',
#   'numero_reviews': 3698,
#   'rating': 4.5,
#   'precio_rango_min': 125,
#   'precio_rango_max': 233,
#   'precio_medio_por noche': 179.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d232778-Reviews-Hotel_Arc_La_Rambla-Barcelona_Catalonia.html'},
#  {'nombre': 'Generator Barcelona',
#   'numero_reviews': 2388,
#   'rating': 4,
#   'precio_rango_min': 63,
#   'precio_rango_max': 206,
#   'precio_medio_por noche': 134.5,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi', 'Restaurant', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d3540235-Reviews-Generator_Barcelona-Barcelona_Catalonia.html'},
#  {'nombre': 'Castell Beach Aparthotel',
#   'numero_reviews': 5,
#   'rating': 4.5,
#   'precio_rango_min': 78,
#   'precio_rango_max': 128,
#   'precio_medio_por noche': 103.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Beachfront', 'Outdoor pool'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d23462515-Reviews-Castell_Beach_Aparthotel-Barcelona_Catalonia.html'},
#  {'nombre': 'Hotel Colón',
#   'numero_reviews': 3042,
#   'rating': 4.5,
#   'precio_rango_min': 255,
#   'precio_rango_max': 407,
#   'precio_medio_por noche': 331.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi', 'Restaurant', 'Room service', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d190823-Reviews-Hotel_Colon-Barcelona_Catalonia.html'},
#  {'nombre': 'Casa Camper Hotel Barcelona',
#   'numero_reviews': 2632,
#   'rating': 5,
#   'precio_rango_min': 233,
#   'precio_rango_max': 404,
#   'precio_medio_por noche': 318.5,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi', 'Bar/Lounge', 'Fitness center'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d543153-Reviews-Casa_Camper_Hotel_Barcelona-Barcelona_Catalonia.html'},
#  {'nombre': 'Casa Gracia',
#   'numero_reviews': 1937,
#   'rating': 4,
#   'precio_rango_min': 119,
#   'precio_rango_max': 223,
#   'precio_medio_por noche': 171.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi', 'Airport transportation', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d1948832-Reviews-Casa_Gracia-Barcelona_Catalonia.html'},
#  {'nombre': 'Hotel 1898',
#   'numero_reviews': 6765,
#   'rating': 4.5,
#   'precio_rango_min': 210,
#   'precio_rango_max': 425,
#   'precio_medio_por noche': 317.5,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Pool',
#    'Heated pool',
#    'Indoor pool',
#    'Outdoor pool'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d506158-Reviews-Hotel_1898-Barcelona_Catalonia.html'},
#  {'nombre': 'Barceló Sants',
#   'numero_reviews': 5798,
#   'rating': 4.5,
#   'precio_rango_min': 130,
#   'precio_rango_max': 232,
#   'precio_medio_por noche': 181.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Restaurant',
#    'Room service',
#    'Bar/Lounge',
#    'Fitness center'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d228507-Reviews-Barcelo_Sants-Barcelona_Catalonia.html'},
#  {'nombre': 'Hotel Alimara Barcelona',
#   'numero_reviews': 1163,
#   'rating': 4,
#   'precio_rango_min': 107,
#   'precio_rango_max': 180,
#   'precio_medio_por noche': 143.5,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Restaurant',
#    'Room service',
#    'Bar/Lounge',
#    'Fitness center'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d228464-Reviews-Hotel_Alimara_Barcelona-Barcelona_Catalonia.html'},
#  {'nombre': 'Can Seuba',
#   'numero_reviews': 17,
#   'rating': 4,
#   'precio_rango_min': 55,
#   'precio_rango_max': 87,
#   'precio_medio_por noche': 71.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi', 'Pets Allowed', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d2663628-Reviews-Can_Seuba-Barcelona_Catalonia.html'},
#  {'nombre': 'Torre Melina Gran Meliá',
#   'numero_reviews': 46,
#   'rating': 4,
#   'precio_rango_min': 234,
#   'precio_rango_max': 373,
#   'precio_medio_por noche': 303.5,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Pool',
#    'Outdoor pool',
#    'Restaurant',
#    'Room service'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d208210-Reviews-Torre_Melina_Gran_Melia-Barcelona_Catalonia.html'},
#  {'nombre': 'Ibis Barcelona Meridiana',
#   'numero_reviews': 1478,
#   'rating': 4,
#   'precio_rango_min': 91,
#   'precio_rango_max': 153,
#   'precio_medio_por noche': 122.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi', 'Restaurant', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d231518-Reviews-Ibis_Barcelona_Meridiana-Barcelona_Catalonia.html'},
#  {'nombre': 'ibis Styles Barcelona City Bogatell',
#   'numero_reviews': 1119,
#   'rating': 4.5,
#   'precio_rango_min': 131,
#   'precio_rango_max': 228,
#   'precio_medio_por noche': 179.5,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Breakfast included',
#    'Pool',
#    'Outdoor pool',
#    'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d10670124-Reviews-Ibis_Styles_Barcelona_City_Bogatell-Barcelona_Catalonia.html'},
#  {'nombre': 'Apartamentos Hesperia Barcelona Sant Joan',
#   'numero_reviews': 1046,
#   'rating': 4,
#   'precio_rango_min': 91,
#   'precio_rango_max': 135,
#   'precio_medio_por noche': 113.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Pool',
#    'Outdoor pool',
#    'Restaurant',
#    'Room service'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d228592-Reviews-Apartamentos_Hesperia_Barcelona_Sant_Joan-Barcelona_Catalonia.html'},
#  {'nombre': 'INNSiDE by Meliá Barcelona Apolo',
#   'numero_reviews': 142,
#   'rating': 4.5,
#   'precio_rango_min': 176,
#   'precio_rango_max': 332,
#   'precio_medio_por noche': 254.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Restaurant',
#    'Room service',
#    'Pets Allowed',
#    'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d231502-Reviews-INNSiDE_by_Melia_Barcelona_Apolo-Barcelona_Catalonia.html'},
#  {'nombre': 'Travelodge Barcelona Fira',
#   'numero_reviews': 424,
#   'rating': 4,
#   'precio_rango_min': 80,
#   'precio_rango_max': 177,
#   'precio_medio_por noche': 128.5,
#   'ciudad': 'Barcelona',
#   'servicios': ['Restaurant', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d601350-Reviews-Travelodge_Barcelona_Fira-Barcelona_Catalonia.html'},
#  {'nombre': 'INNSiDE by Meliá Barcelona Apolo',
#   'numero_reviews': 142,
#   'rating': 4.5,
#   'precio_rango_min': 176,
#   'precio_rango_max': 332,
#   'precio_medio_por noche': 254.0,
#   'ciudad': 'Barcelona',
#   'servicios': ['Free Wifi',
#    'Restaurant',
#    'Room service',
#    'Pets Allowed',
#    'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187497-d231502-Reviews-INNSiDE_by_Melia_Barcelona_Apolo-Barcelona_Catalonia.html'}]

# %%
extraer_informacion_hoteles(respuesta2)
# Out:
# [{'nombre': 'Hotel Spa Relais & Chateaux A Quinta da Auga',
#   'numero_reviews': 1116,
#   'rating': 4.5,
#   'precio_rango_min': 207,
#   'precio_rango_max': 297,
#   'precio_medio_por noche': 252.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi',
#    'Free parking',
#    'Breakfast included',
#    'Heated pool',
#    'Indoor pool'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1510515-Reviews-Hotel_Spa_Relais_Chateaux_A_Quinta_da_Auga-Santiago_de_Compostela_Province_of_A_Coruna.html'},
#  {'nombre': 'NH Collection Santiago de Compostela',
#   'numero_reviews': 2316,
#   'rating': 4.5,
#   'precio_rango_min': 97,
#   'precio_rango_max': 177,
#   'precio_medio_por noche': 137.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi',
#    'Free parking',
#    'Pool',
#    'Heated pool',
#    'Indoor pool'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d584984-Reviews-NH_Collection_Santiago_de_Compostela-Santiago_de_Compostela_Province_of_A_Coruna_Galici.html'},
#  {'nombre': 'Hotel Compostela',
#   'numero_reviews': 764,
#   'rating': 4,
#   'precio_rango_min': 71,
#   'precio_rango_max': 177,
#   'precio_medio_por noche': 124.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Room service', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d248531-Reviews-Hotel_Compostela-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Restaurante Asador De Roxos Casa Albardonedo',
#   'numero_reviews': 233,
#   'rating': 4.5,
#   'precio_rango_min': 88,
#   'precio_rango_max': 94,
#   'precio_medio_por noche': 91.0,
#   'ciudad': 'Roxos',
#   'servicios': ['Free Wifi',
#    'Free parking',
#    'Breakfast included',
#    'Restaurant',
#    'Pets Allowed'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g1870402-d1836140-Reviews-Hotel_Restaurante_Asador_De_Roxos_Casa_Albardonedo-Roxos_Santiago_de_Compostela_Provi.html'},
#  {'nombre': 'Gran Hotel Los Abetos',
#   'numero_reviews': 808,
#   'rating': 4.5,
#   'precio_rango_min': 91,
#   'precio_rango_max': 180,
#   'precio_medio_por noche': 135.5,
#   'ciudad': None,
#   'servicios': ['Free Wifi',
#    'Free parking',
#    'Outdoor pool',
#    'Restaurant',
#    'Room service'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d231702-Reviews-Gran_Hotel_Los_Abetos-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Plaza Obradoiro',
#   'numero_reviews': 17,
#   'rating': 4.5,
#   'precio_rango_min': 79,
#   'precio_rango_max': 244,
#   'precio_medio_por noche': 161.5,
#   'ciudad': None,
#   'servicios': ['Free Wifi'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d25075247-Reviews-Hotel_Plaza_Obradoiro-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Casa Grande do Bachao',
#   'numero_reviews': 431,
#   'rating': 5,
#   'precio_rango_min': 113,
#   'precio_rango_max': 128,
#   'precio_medio_por noche': 120.5,
#   'ciudad': None,
#   'servicios': ['Free parking',
#    'Pool',
#    'Outdoor pool',
#    'Restaurant',
#    'Pets Allowed'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d578149-Reviews-Casa_Grande_do_Bachao-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Monte do Gozo',
#   'numero_reviews': 11,
#   'rating': 3.5,
#   'precio_rango_min': 43,
#   'precio_rango_max': 59,
#   'precio_medio_por noche': 51.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi',
#    'Free parking',
#    'Pool',
#    'Restaurant',
#    'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d17644326-Reviews-Monte_do_Gozo-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'La  Credencial',
#   'numero_reviews': 43,
#   'rating': 4.5,
#   'precio_rango_min': 24,
#   'precio_rango_max': 40,
#   'precio_medio_por noche': 32.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d10090105-Reviews-La_Credencial-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Santiago Apostol',
#   'numero_reviews': 338,
#   'rating': 3.5,
#   'precio_rango_min': 55,
#   'precio_rango_max': 103,
#   'precio_medio_por noche': 79.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Free parking', 'Restaurant', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d228528-Reviews-Hotel_Santiago_Apostol-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Eurostars San Lazaro',
#   'numero_reviews': 555,
#   'rating': 4,
#   'precio_rango_min': 62,
#   'precio_rango_max': 140,
#   'precio_medio_por noche': 101.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi',
#    'Free parking',
#    'Restaurant',
#    'Room service',
#    'Pets Allowed'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d482510-Reviews-Eurostars_San_Lazaro-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Altaïr',
#   'numero_reviews': 608,
#   'rating': 4.5,
#   'precio_rango_min': 81,
#   'precio_rango_max': 163,
#   'precio_medio_por noche': 122.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d583203-Reviews-Hotel_Altair-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Exe Peregrino',
#   'numero_reviews': 38,
#   'rating': 4,
#   'precio_rango_min': 65,
#   'precio_rango_max': 142,
#   'precio_medio_por noche': 103.5,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Pool', 'Restaurant'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d24121482-Reviews-Exe_Peregrino-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Rua Villar',
#   'numero_reviews': 315,
#   'rating': 4.5,
#   'precio_rango_min': 76,
#   'precio_rango_max': 168,
#   'precio_medio_por noche': 122.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d483859-Reviews-Hotel_Rua_Villar-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Oca Puerta del Camino',
#   'numero_reviews': 649,
#   'rating': 4,
#   'precio_rango_min': 62,
#   'precio_rango_max': 141,
#   'precio_medio_por noche': 101.5,
#   'ciudad': None,
#   'servicios': ['Free Wifi',
#    'Pool',
#    'Outdoor pool',
#    'Restaurant',
#    'Airport transportation'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d234585-Reviews-Hotel_Oca_Puerta_del_Camino-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Santiago Plaza Affiliated by Melia',
#   'numero_reviews': 940,
#   'rating': 4,
#   'precio_rango_min': 68,
#   'precio_rango_max': 168,
#   'precio_medio_por noche': 118.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Restaurant', 'Room service', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d234587-Reviews-Hotel_Santiago_Plaza_Affiliated_by_Melia-Santiago_de_Compostela_Province_of_A_Coruna_Ga.html'},
#  {'nombre': 'Hotel Montes',
#   'numero_reviews': 4,
#   'rating': 4.5,
#   'precio_rango_min': 82,
#   'precio_rango_max': 194,
#   'precio_medio_por noche': 138.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Airport transportation', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d3472761-Reviews-Hotel_Montes-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Alda San Carlos',
#   'numero_reviews': 256,
#   'rating': 4,
#   'precio_rango_min': 52,
#   'precio_rango_max': 156,
#   'precio_medio_por noche': 104.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d244677-Reviews-Hotel_Alda_San_Carlos-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel San Lazaro',
#   'numero_reviews': 181,
#   'rating': 4,
#   'precio_rango_min': 55,
#   'precio_rango_max': 91,
#   'precio_medio_por noche': 73.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Restaurant', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1389231-Reviews-Hotel_San_Lazaro-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Bonaval',
#   'numero_reviews': 289,
#   'rating': 4.5,
#   'precio_rango_min': 48,
#   'precio_rango_max': 135,
#   'precio_medio_por noche': 91.5,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Breakfast included', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1160876-Reviews-Hotel_Bonaval-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Eurostars Gran Hotel Santiago',
#   'numero_reviews': 559,
#   'rating': 4,
#   'precio_rango_min': 68,
#   'precio_rango_max': 156,
#   'precio_medio_por noche': 112.0,
#   'ciudad': None,
#   'servicios': ['Restaurant', 'Room service', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d501752-Reviews-Eurostars_Gran_Hotel_Santiago-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Windsor',
#   'numero_reviews': 200,
#   'rating': 4,
#   'precio_rango_min': 47,
#   'precio_rango_max': 80,
#   'precio_medio_por noche': 63.5,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1389234-Reviews-Hotel_Windsor-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Plaza Obradoiro',
#   'numero_reviews': 17,
#   'rating': 4.5,
#   'precio_rango_min': 79,
#   'precio_rango_max': 244,
#   'precio_medio_por noche': 161.5,
#   'ciudad': None,
#   'servicios': ['Free Wifi'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d25075247-Reviews-Hotel_Plaza_Obradoiro-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Restaurante San Paio',
#   'numero_reviews': 65,
#   'rating': 3,
#   'precio_rango_min': 65,
#   'precio_rango_max': 69,
#   'precio_medio_por noche': 67.0,
#   'ciudad': None,
#   'servicios': ['Restaurant', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1389246-Reviews-Hotel_Restaurante_San_Paio-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Moure Hotel',
#   'numero_reviews': 368,
#   'rating': 4.5,
#   'precio_rango_min': 81,
#   'precio_rango_max': 171,
#   'precio_medio_por noche': 126.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Breakfast included', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1389221-Reviews-Moure_Hotel-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Carris Casa de la Troya',
#   'numero_reviews': 452,
#   'rating': 4.5,
#   'precio_rango_min': 76,
#   'precio_rango_max': 204,
#   'precio_medio_por noche': 140.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Room service', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1983523-Reviews-Hotel_Carris_Casa_de_la_Troya-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Castro',
#   'numero_reviews': 107,
#   'rating': 3.5,
#   'precio_rango_min': 50,
#   'precio_rango_max': 78,
#   'precio_medio_por noche': 64.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Free parking', 'Restaurant', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d577883-Reviews-Hotel_Castro-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Moure Hotel',
#   'numero_reviews': 368,
#   'rating': 4.5,
#   'precio_rango_min': 81,
#   'precio_rango_max': 171,
#   'precio_medio_por noche': 126.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Breakfast included', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d1389221-Reviews-Moure_Hotel-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Congreso',
#   'numero_reviews': 922,
#   'rating': 3.5,
#   'precio_rango_min': 58,
#   'precio_rango_max': 75,
#   'precio_medio_por noche': 66.5,
#   'ciudad': None,
#   'servicios': ['Free Wifi',
#    'Free parking',
#    'Pool',
#    'Outdoor pool',
#    'Restaurant'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d232804-Reviews-Hotel_Congreso-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Smart Boutique Hotel Literario San Bieito',
#   'numero_reviews': 345,
#   'rating': 4.5,
#   'precio_rango_min': 60,
#   'precio_rango_max': 173,
#   'precio_medio_por noche': 116.5,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Breakfast included', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d5865931-Reviews-Smart_Boutique_Hotel_Literario_San_Bieito-Santiago_de_Compostela_Province_of_A_Coruna_.html'},
#  {'nombre': 'Hotel Universal',
#   'numero_reviews': 541,
#   'rating': 3.5,
#   'precio_rango_min': 50,
#   'precio_rango_max': 100,
#   'precio_medio_por noche': 75.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d238611-Reviews-Hotel_Universal-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Hotel Exe Area Central',
#   'numero_reviews': 354,
#   'rating': 3.5,
#   'precio_rango_min': 58,
#   'precio_rango_max': 141,
#   'precio_medio_por noche': 99.5,
#   'ciudad': None,
#   'servicios': ['Free Wifi'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d238654-Reviews-Hotel_Exe_Area_Central-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'},
#  {'nombre': 'Apartamentos Cancelas By Bossh Hotels',
#   'numero_reviews': 30,
#   'rating': 3,
#   'precio_rango_min': 49,
#   'precio_rango_max': 91,
#   'precio_medio_por noche': 70.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Free parking'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d10265761-Reviews-Apartamentos_Cancelas_By_Bossh_Hotels-Santiago_de_Compostela_Province_of_A_Coruna_Gal.html'},
#  {'nombre': 'Hotel Altaïr',
#   'numero_reviews': 608,
#   'rating': 4.5,
#   'precio_rango_min': 81,
#   'precio_rango_max': 163,
#   'precio_medio_por noche': 122.0,
#   'ciudad': None,
#   'servicios': ['Free Wifi', 'Bar/Lounge'],
#   'link': 'https://www.tripadvisor.com/Hotel_Review-g187508-d583203-Reviews-Hotel_Altair-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html'}]

# %%
def crear_df_hoteles(funcion_extraer_informacion_hoteles):
    """
    Crea y devuelve un DataFrame a partir de la información de hoteles obtenida.

    La función recibe una lista de diccionarios generada por la función `extraer_informacion_hoteles`, 
    convierte esa lista en un DataFrame y elimina las columnas "precio_rango_min" y "precio_rango_max",
    manteniendo solo la información relevante para el análisis.

    Args:
        funcion_extraer_informacion_hoteles (list[dict]): Lista de diccionarios con información sobre hoteles, 
        obtenida de la función `extraer_informacion_hoteles`.

    Returns:
        pd.DataFrame: Un DataFrame con los datos de hoteles, excluyendo las columnas "precio_rango_min" y "precio_rango_max".
    """

    df_hotel= pd.DataFrame(funcion_extraer_informacion_hoteles).drop(columns= ["precio_rango_min", "precio_rango_max"])
    pd.set_option('display.max_colwidth', None)

    df_hotel
    return df_hotel

# %%
df_hoteles_barcelona=crear_df_hoteles(extraer_informacion_hoteles(respuesta))
df_hoteles_barcelona.head()
# Out:
#                            nombre  numero_reviews  rating  \
# 0                   Andante Hotel            2817     4.5
# 1   Hyatt Regency Barcelona Tower            3566     4.5
# 2                   Hotel Astoria            1900     4.5
# 3  Majestic Hotel & Spa Barcelona            4259     4.5
# 4      Hotel Catalonia Park Güell            1417     3.5
#
#    precio_medio_por noche     ciudad  \
# 0                   195.5  Barcelona
# 1                   241.0  Barcelona
# 2                   175.5  Barcelona
# 3                   446.0  Barcelona
# 4                   135.5  Barcelona
#
#                                                              servicios  \
# 0                      [Free Wifi, Pool, Outdoor pool, Fitness center]
# 1              [Free Wifi, Pool, Heated pool, Indoor pool, Restaurant]
# 2            [Free Wifi, Pool, Outdoor pool, Restaurant, Room service]
# 3  [Free Wifi, Pool, Outdoor pool, Restaurant, Airport transportation]
# 4    [Free Wifi, Outdoor pool, Restaurant, Room service, Pets Allowed]
#
#                                                                                                                       link
# 0                 https://www.tripadvisor.com/Hotel_Review-g187497-d2545026-Reviews-Andante_Hotel-Barcelona_Catalonia.html
# 1  https://www.tripadvisor.com/Hotel_Review-g187497-d630596-Reviews-Hyatt_Regency_Barcelona_Tower-Barcelona_Catalonia.html
# 2                  https://www.tripadvisor.com/Hotel_Review-g187497-d228590-Reviews-Hotel_Astoria-Barcelona_Catalonia.html
# 3   https://www.tripadvisor.com/Hotel_Review-g187497-d190616-Reviews-Majestic_Hotel_Spa_Barcelona-Barcelona_Catalonia.html
# 4     https://www.tripadvisor.com/Hotel_Review-g187497-d236194-Reviews-Hotel_Catalonia_Park_Guell-Barcelona_Catalonia.html

# %%
df_hoteles_santiago=crear_df_hoteles(extraer_informacion_hoteles(respuesta2))
df_hoteles_santiago.head()
# Out:
#                                                nombre  numero_reviews  rating  \
# 0        Hotel Spa Relais & Chateaux A Quinta da Auga            1116     4.5
# 1                NH Collection Santiago de Compostela            2316     4.5
# 2                                    Hotel Compostela             764     4.0
# 3  Hotel Restaurante Asador De Roxos Casa Albardonedo             233     4.5
# 4                               Gran Hotel Los Abetos             808     4.5
#
#    precio_medio_por noche ciudad  \
# 0                   252.0   None
# 1                   137.0   None
# 2                   124.0   None
# 3                    91.0  Roxos
# 4                   135.5   None
#
#                                                                  servicios  \
# 0  [Free Wifi, Free parking, Breakfast included, Heated pool, Indoor pool]
# 1                [Free Wifi, Free parking, Pool, Heated pool, Indoor pool]
# 2                                    [Free Wifi, Room service, Bar/Lounge]
# 3  [Free Wifi, Free parking, Breakfast included, Restaurant, Pets Allowed]
# 4        [Free Wifi, Free parking, Outdoor pool, Restaurant, Room service]
#
#                                                                                                                                                             link
# 0  https://www.tripadvisor.com/Hotel_Review-g187508-d1510515-Reviews-Hotel_Spa_Relais_Chateaux_A_Quinta_da_Auga-Santiago_de_Compostela_Province_of_A_Coruna.html
# 1  https://www.tripadvisor.com/Hotel_Review-g187508-d584984-Reviews-NH_Collection_Santiago_de_Compostela-Santiago_de_Compostela_Province_of_A_Coruna_Galici.html
# 2                     https://www.tripadvisor.com/Hotel_Review-g187508-d248531-Reviews-Hotel_Compostela-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html
# 3  https://www.tripadvisor.com/Hotel_Review-g1870402-d1836140-Reviews-Hotel_Restaurante_Asador_De_Roxos_Casa_Albardonedo-Roxos_Santiago_de_Compostela_Provi.html
# 4                https://www.tripadvisor.com/Hotel_Review-g187508-d231702-Reviews-Gran_Hotel_Los_Abetos-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html

# %% [markdown]
# Veamos si es necesario limpiar los dataframes que acabamos de obtener

# %%
df_hoteles_barcelona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   nombre                  31 non-null     object
#  1   numero_reviews          31 non-null     int64
#  2   rating                  31 non-null     float64
#  3   precio_medio_por noche  31 non-null     float64
#  4   ciudad                  31 non-null     object
#  5   servicios               31 non-null     object
#  6   link                    31 non-null     object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.8+ KB

# %%
df_hoteles_santiago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   nombre                  34 non-null     object
#  1   numero_reviews          34 non-null     int64
#  2   rating                  34 non-null     float64
#  3   precio_medio_por noche  34 non-null     float64
#  4   ciudad                  1 non-null      object
#  5   servicios               34 non-null     object
#  6   link                    34 non-null     object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.0+ KB

# %% [markdown]
# Observamos que los tipos de datos son coherentes y manejables para el análisis en ambos dataframes. En cuanto a valores nulos, el dataframe de barcelona, no tiene ninguno, mientras que el de santiago los acumula en la columna ciudad. Esto es fácilmente solucionable, rellenando nosotros esos valores pues sabems que la ciudad es Santiago de Compostela.

# %%
df_hoteles_santiago['ciudad'] = 'Santiago de Compostela'
df_hoteles_santiago.head()
# Out:
#                                                nombre  numero_reviews  rating  \
# 0        Hotel Spa Relais & Chateaux A Quinta da Auga            1116     4.5
# 1                NH Collection Santiago de Compostela            2316     4.5
# 2                                    Hotel Compostela             764     4.0
# 3  Hotel Restaurante Asador De Roxos Casa Albardonedo             233     4.5
# 4                               Gran Hotel Los Abetos             808     4.5
#
#    precio_medio_por noche                  ciudad  \
# 0                   252.0  Santiago de Compostela
# 1                   137.0  Santiago de Compostela
# 2                   124.0  Santiago de Compostela
# 3                    91.0  Santiago de Compostela
# 4                   135.5  Santiago de Compostela
#
#                                                                  servicios  \
# 0  [Free Wifi, Free parking, Breakfast included, Heated pool, Indoor pool]
# 1                [Free Wifi, Free parking, Pool, Heated pool, Indoor pool]
# 2                                    [Free Wifi, Room service, Bar/Lounge]
# 3  [Free Wifi, Free parking, Breakfast included, Restaurant, Pets Allowed]
# 4        [Free Wifi, Free parking, Outdoor pool, Restaurant, Room service]
#
#                                                                                                                                                             link
# 0  https://www.tripadvisor.com/Hotel_Review-g187508-d1510515-Reviews-Hotel_Spa_Relais_Chateaux_A_Quinta_da_Auga-Santiago_de_Compostela_Province_of_A_Coruna.html
# 1  https://www.tripadvisor.com/Hotel_Review-g187508-d584984-Reviews-NH_Collection_Santiago_de_Compostela-Santiago_de_Compostela_Province_of_A_Coruna_Galici.html
# 2                     https://www.tripadvisor.com/Hotel_Review-g187508-d248531-Reviews-Hotel_Compostela-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html
# 3  https://www.tripadvisor.com/Hotel_Review-g1870402-d1836140-Reviews-Hotel_Restaurante_Asador_De_Roxos_Casa_Albardonedo-Roxos_Santiago_de_Compostela_Provi.html
# 4                https://www.tripadvisor.com/Hotel_Review-g187508-d231702-Reviews-Gran_Hotel_Los_Abetos-Santiago_de_Compostela_Province_of_A_Coruna_Galicia.html

# %% [markdown]
# Comprobemos por último si hay filas duplicadas y en caso de haberlas eliminamos el duplicado

# %%
#Excluimos de la comprobación la columna servicios, que da problemas por contener lsitas en cada fila
num_filas_duplicadas = df_hoteles_barcelona.drop(columns=['servicios']).duplicated().value_counts()
num_filas_duplicadas
# Out:
# False    30
# True      1
# Name: count, dtype: int64

# %%
# Para eliminar la fila duplicada, no nos vale aplicar directamente drop_duplicates
# por ser "servicios" una columna de listas

df_auxiliar = df_hoteles_barcelona.drop(columns=['servicios'])


filas_no_duplicadas = ~df_auxiliar.duplicated()

# Obtenemos el dataFrame original filtrado para eliminar las filas duplicadas
df_hoteles_barcelona = df_hoteles_barcelona[filas_no_duplicadas].reset_index(drop=True)

# %%
df_hoteles_barcelona.drop(columns=['servicios']).duplicated().value_counts() #vemos que ya no hay duplicados
# Out:
# False    30
# Name: count, dtype: int64

# %%
# Mismo proceso para el DataFrame de Santiago de Compostela
num_filas_duplicadas = df_hoteles_barcelona.drop(columns=['servicios']).duplicated().value_counts()
num_filas_duplicadas
# Out:
# False    30
# Name: count, dtype: int64

# %% [markdown]
# En este caso, el de Santiago no tiene duplicados, por lo que termina aquí la limpieza de ambos DataFrames

# %% [markdown]
# **Vuelos con Skyscraper**

# %%
url = "https://sky-scrapper.p.rapidapi.com/api/v2/flights/searchFlights"

querystring = {
    "originSkyId": "MAD",  # Código para Madrid
    "destinationSkyId": "SCQ",  # Código para Santiago de Compostela
    "originEntityId": "95565077",  # Id de Madrid
    "destinationEntityId": "95565108",  # Id de Santiago de Compostela
    "date": "2024-11-22",
    "returnDate":"2024-11-24",
    "cabinClass": "economy",
    "adults": "2",
    "sortBy": "best",
    "limit":50,
    "currency": "EUR",
}

headers = {
    "x-rapidapi-key": key,
    "x-rapidapi-host": "sky-scrapper.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

vuelo_santiago = response.json()

# %%
vuelo_santiago
# Out:
# {'status': True,
#  'timestamp': 1729452287266,
#  'sessionId': 'd14a4a6c-a611-44ef-ac04-8c19d23af4c2',
#  'data': {'context': {'status': 'incomplete',
#    'sessionId': 'ClQIARJQCk4KJGQxNGE0YTZjLWE2MTEtNDRlZi1hYzA0LThjMTlkMjNhZjRjMhACGiQyNjIxZmIzNi1mM2U1LTRhMjYtYmQ5YS02OTQxODUyYTU1YzQSKHVzc181N2ViNWY1Ni01ZDE3LTRmN2YtYTNjMS0wMjQwNTE5ZmRkNzk=',
#    'totalResults': 10},
#   'itineraries': [{'id': '13870-2411221055--31915-0-16142-2411221215|16142-2411240805--31915-0-13870-2411240920',
#     'price': {'raw': 88.9,
#      'formatted': '89 €',
#      'pricingOptionId': 'o8tWlBOBv3Dh'},
#     'legs': [{'id': '13870-2411221055--31915-0-16142-2411221215',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 80,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T10:55:00',
#       'arrival': '2024-11-22T12:15:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -31915,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/FR.png',
#          'name': 'Ryanair'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-16142-2411221055-2411221215--31915',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T10:55:00',
#         'arrival': '2024-11-22T12:15:00',
#         'durationInMinutes': 80,
#         'flightNumber': '5315',
#         'marketingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '16142-2411240805--31915-0-13870-2411240920',
#       'origin': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T08:05:00',
#       'arrival': '2024-11-24T09:20:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -31915,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/FR.png',
#          'name': 'Ryanair'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '16142-13870-2411240805-2411240920--31915',
#         'origin': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T08:05:00',
#         'arrival': '2024-11-24T09:20:00',
#         'durationInMinutes': 75,
#         'flightNumber': '5316',
#         'marketingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'eco': {'ecoContenderDelta': 16.157616},
#     'fareAttributes': {},
#     'tags': ['cheapest'],
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.999},
#    {'id': '13870-2411221150--32222-0-16142-2411221305|16142-2411241345--32222-0-13870-2411241500',
#     'price': {'raw': 178.94,
#      'formatted': '179 €',
#      'pricingOptionId': 'pbMP1jR64NIe'},
#     'legs': [{'id': '13870-2411221150--32222-0-16142-2411221305',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T11:50:00',
#       'arrival': '2024-11-22T13:05:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-16142-2411221150-2411221305--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T11:50:00',
#         'arrival': '2024-11-22T13:05:00',
#         'durationInMinutes': 75,
#         'flightNumber': '519',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '16142-2411241345--32222-0-13870-2411241500',
#       'origin': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T13:45:00',
#       'arrival': '2024-11-24T15:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operating': [{'id': -32221,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/I2.png',
#          'name': 'Iberia Express'}],
#        'operationType': 'not_operated'},
#       'segments': [{'id': '16142-13870-2411241345-2411241500--32222',
#         'origin': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T13:45:00',
#         'arrival': '2024-11-24T15:00:00',
#         'durationInMinutes': 75,
#         'flightNumber': '1996',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32221,
#          'name': 'Iberia Express',
#          'alternateId': 'I2',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'eco': {'ecoContenderDelta': 17.802084},
#     'fareAttributes': {},
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.878333},
#    {'id': '13870-2411220730--32222-0-16142-2411220845|16142-2411241345--32222-0-13870-2411241500',
#     'price': {'raw': 134,
#      'formatted': '134 €',
#      'pricingOptionId': 'rTBgl3FiADby'},
#     'legs': [{'id': '13870-2411220730--32222-0-16142-2411220845',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T07:30:00',
#       'arrival': '2024-11-22T08:45:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-16142-2411220730-2411220845--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T07:30:00',
#         'arrival': '2024-11-22T08:45:00',
#         'durationInMinutes': 75,
#         'flightNumber': '517',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '16142-2411241345--32222-0-13870-2411241500',
#       'origin': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T13:45:00',
#       'arrival': '2024-11-24T15:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operating': [{'id': -32221,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/I2.png',
#          'name': 'Iberia Express'}],
#        'operationType': 'not_operated'},
#       'segments': [{'id': '16142-13870-2411241345-2411241500--32222',
#         'origin': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T13:45:00',
#         'arrival': '2024-11-24T15:00:00',
#         'durationInMinutes': 75,
#         'flightNumber': '1996',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32221,
#          'name': 'Iberia Express',
#          'alternateId': 'I2',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'eco': {'ecoContenderDelta': 17.802084},
#     'fareAttributes': {},
#     'tags': ['third_cheapest', 'shortest'],
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.729338},
#    {'id': '13870-2411222020--31915-0-16142-2411222140|16142-2411240805--31915-0-13870-2411240920',
#     'price': {'raw': 102.1,
#      'formatted': '103 €',
#      'pricingOptionId': 'R-xf5Lv9_bm-'},
#     'legs': [{'id': '13870-2411222020--31915-0-16142-2411222140',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 80,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T20:20:00',
#       'arrival': '2024-11-22T21:40:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -31915,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/FR.png',
#          'name': 'Ryanair'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-16142-2411222020-2411222140--31915',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T20:20:00',
#         'arrival': '2024-11-22T21:40:00',
#         'durationInMinutes': 80,
#         'flightNumber': '5317',
#         'marketingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '16142-2411240805--31915-0-13870-2411240920',
#       'origin': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T08:05:00',
#       'arrival': '2024-11-24T09:20:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -31915,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/FR.png',
#          'name': 'Ryanair'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '16142-13870-2411240805-2411240920--31915',
#         'origin': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T08:05:00',
#         'arrival': '2024-11-24T09:20:00',
#         'durationInMinutes': 75,
#         'flightNumber': '5316',
#         'marketingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'eco': {'ecoContenderDelta': 23.249811},
#     'fareAttributes': {},
#     'tags': ['second_cheapest'],
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.595944},
#    {'id': '13870-2411221055--31915-0-16142-2411221215|16142-2411241345--32221-0-13870-2411241500',
#     'price': {'raw': 147.72,
#      'formatted': '148 €',
#      'pricingOptionId': '2ffLqQY7JWSL'},
#     'legs': [{'id': '13870-2411221055--31915-0-16142-2411221215',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 80,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T10:55:00',
#       'arrival': '2024-11-22T12:15:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -31915,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/FR.png',
#          'name': 'Ryanair'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-16142-2411221055-2411221215--31915',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T10:55:00',
#         'arrival': '2024-11-22T12:15:00',
#         'durationInMinutes': 80,
#         'flightNumber': '5315',
#         'marketingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '16142-2411241345--32221-0-13870-2411241500',
#       'origin': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T13:45:00',
#       'arrival': '2024-11-24T15:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32221,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/I2.png',
#          'name': 'Iberia Express'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '16142-13870-2411241345-2411241500--32221',
#         'origin': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T13:45:00',
#         'arrival': '2024-11-24T15:00:00',
#         'durationInMinutes': 75,
#         'flightNumber': '1996',
#         'marketingCarrier': {'id': -32221,
#          'name': 'Iberia Express',
#          'alternateId': 'I2',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32221,
#          'name': 'Iberia Express',
#          'alternateId': 'I2',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'eco': {'ecoContenderDelta': 16.979849},
#     'fareAttributes': {},
#     'isMashUp': True,
#     'hasFlexibleOptions': False,
#     'score': 0.58219},
#    {'id': '13870-2411222020--31915-0-16142-2411222140|16142-2411241345--32221-0-13870-2411241500',
#     'price': {'raw': 160.92,
#      'formatted': '161 €',
#      'pricingOptionId': 'fSV8sYtBfMlf'},
#     'legs': [{'id': '13870-2411222020--31915-0-16142-2411222140',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 80,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T20:20:00',
#       'arrival': '2024-11-22T21:40:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -31915,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/FR.png',
#          'name': 'Ryanair'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-16142-2411222020-2411222140--31915',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T20:20:00',
#         'arrival': '2024-11-22T21:40:00',
#         'durationInMinutes': 80,
#         'flightNumber': '5317',
#         'marketingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '16142-2411241345--32221-0-13870-2411241500',
#       'origin': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T13:45:00',
#       'arrival': '2024-11-24T15:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32221,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/I2.png',
#          'name': 'Iberia Express'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '16142-13870-2411241345-2411241500--32221',
#         'origin': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T13:45:00',
#         'arrival': '2024-11-24T15:00:00',
#         'durationInMinutes': 75,
#         'flightNumber': '1996',
#         'marketingCarrier': {'id': -32221,
#          'name': 'Iberia Express',
#          'alternateId': 'I2',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32221,
#          'name': 'Iberia Express',
#          'alternateId': 'I2',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'eco': {'ecoContenderDelta': 24.072044},
#     'fareAttributes': {},
#     'isMashUp': True,
#     'hasFlexibleOptions': False,
#     'score': 0.554682},
#    {'id': '13870-2411221150--32222-0-16142-2411221305|16142-2411241345--32221-0-13870-2411241500',
#     'price': {'raw': 209,
#      'formatted': '209 €',
#      'pricingOptionId': 'b6ZBB5GRAsqA'},
#     'legs': [{'id': '13870-2411221150--32222-0-16142-2411221305',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T11:50:00',
#       'arrival': '2024-11-22T13:05:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-16142-2411221150-2411221305--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T11:50:00',
#         'arrival': '2024-11-22T13:05:00',
#         'durationInMinutes': 75,
#         'flightNumber': '519',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '16142-2411241345--32221-0-13870-2411241500',
#       'origin': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T13:45:00',
#       'arrival': '2024-11-24T15:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32221,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/I2.png',
#          'name': 'Iberia Express'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '16142-13870-2411241345-2411241500--32221',
#         'origin': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T13:45:00',
#         'arrival': '2024-11-24T15:00:00',
#         'durationInMinutes': 75,
#         'flightNumber': '1996',
#         'marketingCarrier': {'id': -32221,
#          'name': 'Iberia Express',
#          'alternateId': 'I2',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32221,
#          'name': 'Iberia Express',
#          'alternateId': 'I2',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'eco': {'ecoContenderDelta': 17.802084},
#     'fareAttributes': {},
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.489416},
#    {'id': '13870-2411220730--32222-0-16142-2411220845|16142-2411241345--32221-0-13870-2411241500',
#     'price': {'raw': 161,
#      'formatted': '161 €',
#      'pricingOptionId': 'tuAYqJCJdIa3'},
#     'legs': [{'id': '13870-2411220730--32222-0-16142-2411220845',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T07:30:00',
#       'arrival': '2024-11-22T08:45:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-16142-2411220730-2411220845--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T07:30:00',
#         'arrival': '2024-11-22T08:45:00',
#         'durationInMinutes': 75,
#         'flightNumber': '517',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '16142-2411241345--32221-0-13870-2411241500',
#       'origin': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T13:45:00',
#       'arrival': '2024-11-24T15:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32221,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/I2.png',
#          'name': 'Iberia Express'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '16142-13870-2411241345-2411241500--32221',
#         'origin': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T13:45:00',
#         'arrival': '2024-11-24T15:00:00',
#         'durationInMinutes': 75,
#         'flightNumber': '1996',
#         'marketingCarrier': {'id': -32221,
#          'name': 'Iberia Express',
#          'alternateId': 'I2',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32221,
#          'name': 'Iberia Express',
#          'alternateId': 'I2',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'eco': {'ecoContenderDelta': 17.802084},
#     'fareAttributes': {},
#     'tags': ['second_shortest'],
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.466437},
#    {'id': '13870-2411220730--32222-0-16142-2411220845|16142-2411242145--32222-0-13870-2411242300',
#     'price': {'raw': 237.38,
#      'formatted': '238 €',
#      'pricingOptionId': 'S0AzDKn66Ld2'},
#     'legs': [{'id': '13870-2411220730--32222-0-16142-2411220845',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T07:30:00',
#       'arrival': '2024-11-22T08:45:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-16142-2411220730-2411220845--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T07:30:00',
#         'arrival': '2024-11-22T08:45:00',
#         'durationInMinutes': 75,
#         'flightNumber': '517',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '16142-2411242145--32222-0-13870-2411242300',
#       'origin': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T21:45:00',
#       'arrival': '2024-11-24T23:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '16142-13870-2411242145-2411242300--32222',
#         'origin': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T21:45:00',
#         'arrival': '2024-11-24T23:00:00',
#         'durationInMinutes': 75,
#         'flightNumber': '524',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'eco': {'ecoContenderDelta': 16.53142},
#     'fareAttributes': {},
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.463801},
#    {'id': '13870-2411221150--32222-0-16142-2411221305|16142-2411240925--32222-0-13870-2411241040',
#     'price': {'raw': 176.64,
#      'formatted': '177 €',
#      'pricingOptionId': 'RcpMDUbhkBv_'},
#     'legs': [{'id': '13870-2411221150--32222-0-16142-2411221305',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T11:50:00',
#       'arrival': '2024-11-22T13:05:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-16142-2411221150-2411221305--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T11:50:00',
#         'arrival': '2024-11-22T13:05:00',
#         'durationInMinutes': 75,
#         'flightNumber': '519',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '16142-2411240925--32222-0-13870-2411241040',
#       'origin': {'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela',
#        'displayCode': 'SCQ',
#        'city': 'Santiago de Compostela',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T09:25:00',
#       'arrival': '2024-11-24T10:40:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '16142-13870-2411240925-2411241040--32222',
#         'origin': {'flightPlaceId': 'SCQ',
#          'displayCode': 'SCQ',
#          'parent': {'flightPlaceId': 'SANC',
#           'displayCode': 'SCQ',
#           'name': 'Santiago de Compostela',
#           'type': 'City'},
#          'name': 'Santiago de Compostela',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T09:25:00',
#         'arrival': '2024-11-24T10:40:00',
#         'durationInMinutes': 75,
#         'flightNumber': '518',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'eco': {'ecoContenderDelta': 16.53142},
#     'fareAttributes': {},
#     'tags': ['third_shortest'],
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.461015}],
#   'messages': [],
#   'filterStats': {'duration': {'min': 75,
#     'max': 80,
#     'multiCityMin': 150,
#     'multiCityMax': 155},
#    'airports': [{'city': 'Madrid',
#      'airports': [{'id': 'MAD', 'entityId': '95565077', 'name': 'Madrid'}]},
#     {'city': 'Santiago de Compostela',
#      'airports': [{'id': 'SCQ',
#        'entityId': '95565108',
#        'name': 'Santiago de Compostela'}]}],
#    'carriers': [{'id': -32222,
#      'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#      'name': 'Iberia'},
#     {'id': -32221,
#      'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/I2.png',
#      'name': 'Iberia Express'},
#     {'id': -31915,
#      'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/FR.png',
#      'name': 'Ryanair'}],
#    'stopPrices': {'direct': {'isPresent': True, 'formattedPrice': '89 €'},
#     'one': {'isPresent': False},
#     'twoOrMore': {'isPresent': False}}},
#   'flightsSessionId': 'd14a4a6c-a611-44ef-ac04-8c19d23af4c2',
#   'destinationImageUrl': 'https://content.skyscnr.com/m/3719e8f4a5daf43d/original/Flights-Placeholder.jpg'}}

# %%
with open('santiago.json', 'w') as archivo:
     json.dump(vuelo_santiago, archivo, indent=4)

# %%
url = "https://sky-scrapper.p.rapidapi.com/api/v2/flights/searchFlights"

querystring = {
    "originSkyId": "MAD",  # Código para Madrid
    "destinationSkyId": "BCN",  # Código para Barcelona
    "originEntityId": "95565077",  # Id de Madrid
    "destinationEntityId": "95565085",  # Id de Barcelona
    "date": "2024-11-22",
    "returnDate":"2024-11-24",
    "cabinClass": "economy",
    "adults": "2",
    "sortBy": "best",
    "limit":50,
    "currency": "EUR",
}

headers = {
    "x-rapidapi-key": key,
    "x-rapidapi-host": "sky-scrapper.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

vuelo_barcelona = response.json()

# %%
vuelo_barcelona
# Out:
# {'status': True,
#  'timestamp': 1729452289840,
#  'sessionId': 'aaf80f2f-78f0-4fc9-a5c2-40ccbeecad63',
#  'data': {'context': {'status': 'incomplete',
#    'sessionId': 'ClQIARJQCk4KJGFhZjgwZjJmLTc4ZjAtNGZjOS1hNWMyLTQwY2NiZWVjYWQ2MxACGiRiYThiNzdlNi03YjE5LTRhMmItYTIwMC03YjM3MDcwYTQzYWISKHVzc19kOGJjMzI5NC1iOWM1LTQxMmEtODAwNy05YTY4MGY5YmViODM=',
#    'totalResults': 10},
#   'itineraries': [{'id': '13870-2411220715--32222-0-9772-2411220830|9772-2411241515--32222-0-13870-2411241640',
#     'price': {'raw': 117.98,
#      'formatted': '118 €',
#      'pricingOptionId': 'xg7VgqueIUeJ'},
#     'legs': [{'id': '13870-2411220715--32222-0-9772-2411220830',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T07:15:00',
#       'arrival': '2024-11-22T08:30:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-9772-2411220715-2411220830--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T07:15:00',
#         'arrival': '2024-11-22T08:30:00',
#         'durationInMinutes': 75,
#         'flightNumber': '403',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '9772-2411241515--32222-0-13870-2411241640',
#       'origin': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T15:15:00',
#       'arrival': '2024-11-24T16:40:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '9772-13870-2411241515-2411241640--32222',
#         'origin': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T15:15:00',
#         'arrival': '2024-11-24T16:40:00',
#         'durationInMinutes': 85,
#         'flightNumber': '414',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'tags': ['second_cheapest', 'second_shortest'],
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.999},
#    {'id': '13870-2411221030--32222-0-9772-2411221145|9772-2411241515--32222-0-13870-2411241640',
#     'price': {'raw': 149.48,
#      'formatted': '150 €',
#      'pricingOptionId': '5aPKtqV_skrI'},
#     'legs': [{'id': '13870-2411221030--32222-0-9772-2411221145',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T10:30:00',
#       'arrival': '2024-11-22T11:45:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-9772-2411221030-2411221145--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T10:30:00',
#         'arrival': '2024-11-22T11:45:00',
#         'durationInMinutes': 75,
#         'flightNumber': '409',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '9772-2411241515--32222-0-13870-2411241640',
#       'origin': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T15:15:00',
#       'arrival': '2024-11-24T16:40:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '9772-13870-2411241515-2411241640--32222',
#         'origin': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T15:15:00',
#         'arrival': '2024-11-24T16:40:00',
#         'durationInMinutes': 85,
#         'flightNumber': '414',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.946382},
#    {'id': '13870-2411220645--32222-0-9772-2411220800|9772-2411241515--32222-0-13870-2411241640',
#     'price': {'raw': 111.98,
#      'formatted': '112 €',
#      'pricingOptionId': 'aSzp1KUysrrx'},
#     'legs': [{'id': '13870-2411220645--32222-0-9772-2411220800',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T06:45:00',
#       'arrival': '2024-11-22T08:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-9772-2411220645-2411220800--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T06:45:00',
#         'arrival': '2024-11-22T08:00:00',
#         'durationInMinutes': 75,
#         'flightNumber': '401',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '9772-2411241515--32222-0-13870-2411241640',
#       'origin': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T15:15:00',
#       'arrival': '2024-11-24T16:40:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '9772-13870-2411241515-2411241640--32222',
#         'origin': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T15:15:00',
#         'arrival': '2024-11-24T16:40:00',
#         'durationInMinutes': 85,
#         'flightNumber': '414',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'tags': ['cheapest', 'shortest'],
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.89742},
#    {'id': '13870-2411221130--32222-0-9772-2411221245|9772-2411241515--32222-0-13870-2411241640',
#     'price': {'raw': 149.48,
#      'formatted': '150 €',
#      'pricingOptionId': 'X3sPCs9YJB4A'},
#     'legs': [{'id': '13870-2411221130--32222-0-9772-2411221245',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T11:30:00',
#       'arrival': '2024-11-22T12:45:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-9772-2411221130-2411221245--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T11:30:00',
#         'arrival': '2024-11-22T12:45:00',
#         'durationInMinutes': 75,
#         'flightNumber': '411',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '9772-2411241515--32222-0-13870-2411241640',
#       'origin': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T15:15:00',
#       'arrival': '2024-11-24T16:40:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '9772-13870-2411241515-2411241640--32222',
#         'origin': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T15:15:00',
#         'arrival': '2024-11-24T16:40:00',
#         'durationInMinutes': 85,
#         'flightNumber': '414',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.861705},
#    {'id': '13870-2411221315--32222-0-9772-2411221430|9772-2411241515--32222-0-13870-2411241640',
#     'price': {'raw': 153.58,
#      'formatted': '154 €',
#      'pricingOptionId': '1iltiwLUdr25'},
#     'legs': [{'id': '13870-2411221315--32222-0-9772-2411221430',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T13:15:00',
#       'arrival': '2024-11-22T14:30:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-9772-2411221315-2411221430--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T13:15:00',
#         'arrival': '2024-11-22T14:30:00',
#         'durationInMinutes': 75,
#         'flightNumber': '413',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '9772-2411241515--32222-0-13870-2411241640',
#       'origin': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T15:15:00',
#       'arrival': '2024-11-24T16:40:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '9772-13870-2411241515-2411241640--32222',
#         'origin': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T15:15:00',
#         'arrival': '2024-11-24T16:40:00',
#         'durationInMinutes': 85,
#         'flightNumber': '414',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.84418},
#    {'id': '13870-2411220830--32222-0-9772-2411220945|9772-2411241515--32222-0-13870-2411241640',
#     'price': {'raw': 141.04,
#      'formatted': '142 €',
#      'pricingOptionId': 'v1Zy0DErWi7n'},
#     'legs': [{'id': '13870-2411220830--32222-0-9772-2411220945',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T08:30:00',
#       'arrival': '2024-11-22T09:45:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-9772-2411220830-2411220945--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T08:30:00',
#         'arrival': '2024-11-22T09:45:00',
#         'durationInMinutes': 75,
#         'flightNumber': '407',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '9772-2411241515--32222-0-13870-2411241640',
#       'origin': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T15:15:00',
#       'arrival': '2024-11-24T16:40:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '9772-13870-2411241515-2411241640--32222',
#         'origin': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T15:15:00',
#         'arrival': '2024-11-24T16:40:00',
#         'durationInMinutes': 85,
#         'flightNumber': '414',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'tags': ['third_shortest'],
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.827321},
#    {'id': '13870-2411220715--32222-0-9772-2411220830|9772-2411242030--31685-0-13870-2411242200',
#     'price': {'raw': 133.96,
#      'formatted': '134 €',
#      'pricingOptionId': 'Oo36nOPBFOyV'},
#     'legs': [{'id': '13870-2411220715--32222-0-9772-2411220830',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T07:15:00',
#       'arrival': '2024-11-22T08:30:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-9772-2411220715-2411220830--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T07:15:00',
#         'arrival': '2024-11-22T08:30:00',
#         'durationInMinutes': 75,
#         'flightNumber': '403',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '9772-2411242030--31685-0-13870-2411242200',
#       'origin': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 90,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T20:30:00',
#       'arrival': '2024-11-24T22:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -31685,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/07.png',
#          'name': 'Vueling Airlines'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '9772-13870-2411242030-2411242200--31685',
#         'origin': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T20:30:00',
#         'arrival': '2024-11-24T22:00:00',
#         'durationInMinutes': 90,
#         'flightNumber': '1008',
#         'marketingCarrier': {'id': -31685,
#          'name': 'Vueling Airlines',
#          'alternateId': '07',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31685,
#          'name': 'Vueling Airlines',
#          'alternateId': '07',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.822281},
#    {'id': '13870-2411220645--32222-0-9772-2411220800|9772-2411242030--31685-0-13870-2411242200',
#     'price': {'raw': 125.98,
#      'formatted': '126 €',
#      'pricingOptionId': 'chAKuTSaaaq-'},
#     'legs': [{'id': '13870-2411220645--32222-0-9772-2411220800',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T06:45:00',
#       'arrival': '2024-11-22T08:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-9772-2411220645-2411220800--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T06:45:00',
#         'arrival': '2024-11-22T08:00:00',
#         'durationInMinutes': 75,
#         'flightNumber': '401',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '9772-2411242030--31685-0-13870-2411242200',
#       'origin': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 90,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T20:30:00',
#       'arrival': '2024-11-24T22:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -31685,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/07.png',
#          'name': 'Vueling Airlines'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '9772-13870-2411242030-2411242200--31685',
#         'origin': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T20:30:00',
#         'arrival': '2024-11-24T22:00:00',
#         'durationInMinutes': 90,
#         'flightNumber': '1008',
#         'marketingCarrier': {'id': -31685,
#          'name': 'Vueling Airlines',
#          'alternateId': '07',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31685,
#          'name': 'Vueling Airlines',
#          'alternateId': '07',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'tags': ['third_cheapest'],
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.811739},
#    {'id': '13870-2411221510--32680-0-9772-2411221635|9772-2411241515--32222-0-13870-2411241640',
#     'price': {'raw': 136.22,
#      'formatted': '137 €',
#      'pricingOptionId': 'C3WcdY5Jj4gN'},
#     'legs': [{'id': '13870-2411221510--32680-0-9772-2411221635',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T15:10:00',
#       'arrival': '2024-11-22T16:35:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32680,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/UX.png',
#          'name': 'Air Europa'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-9772-2411221510-2411221635--32680',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T15:10:00',
#         'arrival': '2024-11-22T16:35:00',
#         'durationInMinutes': 85,
#         'flightNumber': '7703',
#         'marketingCarrier': {'id': -32680,
#          'name': 'Air Europa',
#          'alternateId': 'UX',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32680,
#          'name': 'Air Europa',
#          'alternateId': 'UX',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '9772-2411241515--32222-0-13870-2411241640',
#       'origin': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T15:15:00',
#       'arrival': '2024-11-24T16:40:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '9772-13870-2411241515-2411241640--32222',
#         'origin': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T15:15:00',
#         'arrival': '2024-11-24T16:40:00',
#         'durationInMinutes': 85,
#         'flightNumber': '414',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.81053},
#    {'id': '13870-2411220830--32222-0-9772-2411220945|9772-2411242030--31685-0-13870-2411242200',
#     'price': {'raw': 152,
#      'formatted': '152 €',
#      'pricingOptionId': 'yVgTeg0RkyRL'},
#     'legs': [{'id': '13870-2411220830--32222-0-9772-2411220945',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 75,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-22T08:30:00',
#       'arrival': '2024-11-22T09:45:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-9772-2411220830-2411220945--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-22T08:30:00',
#         'arrival': '2024-11-22T09:45:00',
#         'durationInMinutes': 75,
#         'flightNumber': '407',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '9772-2411242030--31685-0-13870-2411242200',
#       'origin': {'id': 'BCN',
#        'entityId': '95565085',
#        'name': 'Barcelona',
#        'displayCode': 'BCN',
#        'city': 'Barcelona',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 90,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-11-24T20:30:00',
#       'arrival': '2024-11-24T22:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -31685,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/07.png',
#          'name': 'Vueling Airlines'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '9772-13870-2411242030-2411242200--31685',
#         'origin': {'flightPlaceId': 'BCN',
#          'displayCode': 'BCN',
#          'parent': {'flightPlaceId': 'BARC',
#           'displayCode': 'BCN',
#           'name': 'Barcelona',
#           'type': 'City'},
#          'name': 'Barcelona',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-11-24T20:30:00',
#         'arrival': '2024-11-24T22:00:00',
#         'durationInMinutes': 90,
#         'flightNumber': '1008',
#         'marketingCarrier': {'id': -31685,
#          'name': 'Vueling Airlines',
#          'alternateId': '07',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31685,
#          'name': 'Vueling Airlines',
#          'alternateId': '07',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.810305}],
#   'messages': [],
#   'filterStats': {'duration': {'min': 85,
#     'max': 90,
#     'multiCityMin': 160,
#     'multiCityMax': 170},
#    'airports': [{'city': 'Barcelona',
#      'airports': [{'id': 'BCN', 'entityId': '95565085', 'name': 'Barcelona'}]},
#     {'city': 'Madrid',
#      'airports': [{'id': 'MAD', 'entityId': '95565077', 'name': 'Madrid'}]}],
#    'carriers': [{'id': -32680,
#      'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/UX.png',
#      'name': 'Air Europa'},
#     {'id': -32222,
#      'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#      'name': 'Iberia'},
#     {'id': -31685,
#      'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/07.png',
#      'name': 'Vueling Airlines'}],
#    'stopPrices': {'direct': {'isPresent': True, 'formattedPrice': '112 €'},
#     'one': {'isPresent': False},
#     'twoOrMore': {'isPresent': False}}},
#   'flightsSessionId': 'aaf80f2f-78f0-4fc9-a5c2-40ccbeecad63',
#   'destinationImageUrl': 'https://content.skyscnr.com/m/3719e8f4a5daf43d/original/Flights-Placeholder.jpg'}}

# %%
with open('barcelona.json', 'w') as archivo:
     json.dump(vuelo_barcelona, archivo, indent=4)

# %%
def extraer_informacion_vuelos(respuesta_json):
    """
    Extrae información relevante sobre vuelos a partir de una respuesta JSON de un servicio de itinerarios de vuelos.

    La función itera sobre los vuelos y sus tramos (piernas) en el JSON de respuesta, extrayendo información
    como el precio, aeropuertos de origen y destino, tiempos de salida y llegada, duración del vuelo, escalas y aerolíneas.
    Luego organiza esta información en una lista de diccionarios.

    Args:
        respuesta_json (dict): Un diccionario que representa la respuesta en formato JSON de un servicio de vuelos.

    Returns:
        list[dict]: Una lista de diccionarios, donde cada diccionario contiene la información de un tramo de vuelo con las siguientes claves:
            - id_origen: ID del aeropuerto de origen.
            - ciudad_origen: Nombre de la ciudad de origen.
            - id_destino: ID del aeropuerto de destino.
            - ciudad_destino: Nombre de la ciudad de destino.
            - salida: Hora y fecha de salida del vuelo.
            - llegada: Hora y fecha de llegada del vuelo.
            - duracion(min): Duración del vuelo en minutos.
            - escalas: Número de escalas del vuelo.
            - aerolinea: Nombre de la aerolínea que opera el vuelo.
            - precio: Precio del vuelo (formato raw).
    """
    lista_diccionarios = []
    res = respuesta_json.get("data", {})

    for vuelo in range(0, len(res.get("itineraries", []))): 
        precio = res["itineraries"][vuelo].get("price", {}).get("raw", 0)

        for i in range(0, 2):
            id_origen = res["itineraries"][vuelo]["legs"][i].get("origin", {}).get("id", "N/A")
            origen = res["itineraries"][vuelo]["legs"][i].get("origin", {}).get("city", "N/A")

            id_destino = res["itineraries"][vuelo]["legs"][i].get("destination", {}).get("id", "N/A")
            destino = res["itineraries"][vuelo]["legs"][i].get("destination", {}).get("city", "N/A")

            duracion_minutos = res["itineraries"][vuelo]["legs"][i].get("durationInMinutes", 0)
            escalas = res["itineraries"][vuelo]["legs"][i].get("stopCount", 0)

            salida = res["itineraries"][vuelo]["legs"][i].get("departure", "N/A")
            llegada = res["itineraries"][vuelo]["legs"][i].get("arrival", "N/A")

            aerolinea = res["itineraries"][vuelo]["legs"][i].get("carriers", {}).get("marketing", [{}])[0].get("name", "N/A")

            diccionario_vuelos = {
                "id_origen": id_origen,
                "ciudad_origen": origen,
                "id_destino": id_destino,
                "ciudad_destino": destino,
                "salida": salida,
                "llegada": llegada,
                "duracion(min)": duracion_minutos,
                "escalas": escalas,
                "aerolinea": aerolinea,
                "precio": precio
            }
            lista_diccionarios.append(diccionario_vuelos)
    
    return lista_diccionarios

# %%
extraer_informacion_vuelos(vuelo_santiago)
# Out:
# [{'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'SCQ',
#   'ciudad_destino': 'Santiago de Compostela',
#   'salida': '2024-11-22T10:55:00',
#   'llegada': '2024-11-22T12:15:00',
#   'duracion(min)': 80,
#   'escalas': 0,
#   'aerolinea': 'Ryanair',
#   'precio': 88.9},
#  {'id_origen': 'SCQ',
#   'ciudad_origen': 'Santiago de Compostela',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T08:05:00',
#   'llegada': '2024-11-24T09:20:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Ryanair',
#   'precio': 88.9},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'SCQ',
#   'ciudad_destino': 'Santiago de Compostela',
#   'salida': '2024-11-22T11:50:00',
#   'llegada': '2024-11-22T13:05:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 178.94},
#  {'id_origen': 'SCQ',
#   'ciudad_origen': 'Santiago de Compostela',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T13:45:00',
#   'llegada': '2024-11-24T15:00:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 178.94},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'SCQ',
#   'ciudad_destino': 'Santiago de Compostela',
#   'salida': '2024-11-22T07:30:00',
#   'llegada': '2024-11-22T08:45:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 134},
#  {'id_origen': 'SCQ',
#   'ciudad_origen': 'Santiago de Compostela',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T13:45:00',
#   'llegada': '2024-11-24T15:00:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 134},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'SCQ',
#   'ciudad_destino': 'Santiago de Compostela',
#   'salida': '2024-11-22T20:20:00',
#   'llegada': '2024-11-22T21:40:00',
#   'duracion(min)': 80,
#   'escalas': 0,
#   'aerolinea': 'Ryanair',
#   'precio': 102.1},
#  {'id_origen': 'SCQ',
#   'ciudad_origen': 'Santiago de Compostela',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T08:05:00',
#   'llegada': '2024-11-24T09:20:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Ryanair',
#   'precio': 102.1},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'SCQ',
#   'ciudad_destino': 'Santiago de Compostela',
#   'salida': '2024-11-22T10:55:00',
#   'llegada': '2024-11-22T12:15:00',
#   'duracion(min)': 80,
#   'escalas': 0,
#   'aerolinea': 'Ryanair',
#   'precio': 147.72},
#  {'id_origen': 'SCQ',
#   'ciudad_origen': 'Santiago de Compostela',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T13:45:00',
#   'llegada': '2024-11-24T15:00:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia Express',
#   'precio': 147.72},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'SCQ',
#   'ciudad_destino': 'Santiago de Compostela',
#   'salida': '2024-11-22T20:20:00',
#   'llegada': '2024-11-22T21:40:00',
#   'duracion(min)': 80,
#   'escalas': 0,
#   'aerolinea': 'Ryanair',
#   'precio': 160.92},
#  {'id_origen': 'SCQ',
#   'ciudad_origen': 'Santiago de Compostela',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T13:45:00',
#   'llegada': '2024-11-24T15:00:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia Express',
#   'precio': 160.92},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'SCQ',
#   'ciudad_destino': 'Santiago de Compostela',
#   'salida': '2024-11-22T11:50:00',
#   'llegada': '2024-11-22T13:05:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 209},
#  {'id_origen': 'SCQ',
#   'ciudad_origen': 'Santiago de Compostela',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T13:45:00',
#   'llegada': '2024-11-24T15:00:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia Express',
#   'precio': 209},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'SCQ',
#   'ciudad_destino': 'Santiago de Compostela',
#   'salida': '2024-11-22T07:30:00',
#   'llegada': '2024-11-22T08:45:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 161},
#  {'id_origen': 'SCQ',
#   'ciudad_origen': 'Santiago de Compostela',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T13:45:00',
#   'llegada': '2024-11-24T15:00:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia Express',
#   'precio': 161},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'SCQ',
#   'ciudad_destino': 'Santiago de Compostela',
#   'salida': '2024-11-22T07:30:00',
#   'llegada': '2024-11-22T08:45:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 237.38},
#  {'id_origen': 'SCQ',
#   'ciudad_origen': 'Santiago de Compostela',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T21:45:00',
#   'llegada': '2024-11-24T23:00:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 237.38},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'SCQ',
#   'ciudad_destino': 'Santiago de Compostela',
#   'salida': '2024-11-22T11:50:00',
#   'llegada': '2024-11-22T13:05:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 176.64},
#  {'id_origen': 'SCQ',
#   'ciudad_origen': 'Santiago de Compostela',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T09:25:00',
#   'llegada': '2024-11-24T10:40:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 176.64}]

# %%
extraer_informacion_vuelos(vuelo_barcelona)
# Out:
# [{'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'BCN',
#   'ciudad_destino': 'Barcelona',
#   'salida': '2024-11-22T07:15:00',
#   'llegada': '2024-11-22T08:30:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 117.98},
#  {'id_origen': 'BCN',
#   'ciudad_origen': 'Barcelona',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T15:15:00',
#   'llegada': '2024-11-24T16:40:00',
#   'duracion(min)': 85,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 117.98},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'BCN',
#   'ciudad_destino': 'Barcelona',
#   'salida': '2024-11-22T10:30:00',
#   'llegada': '2024-11-22T11:45:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 149.48},
#  {'id_origen': 'BCN',
#   'ciudad_origen': 'Barcelona',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T15:15:00',
#   'llegada': '2024-11-24T16:40:00',
#   'duracion(min)': 85,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 149.48},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'BCN',
#   'ciudad_destino': 'Barcelona',
#   'salida': '2024-11-22T06:45:00',
#   'llegada': '2024-11-22T08:00:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 111.98},
#  {'id_origen': 'BCN',
#   'ciudad_origen': 'Barcelona',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T15:15:00',
#   'llegada': '2024-11-24T16:40:00',
#   'duracion(min)': 85,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 111.98},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'BCN',
#   'ciudad_destino': 'Barcelona',
#   'salida': '2024-11-22T11:30:00',
#   'llegada': '2024-11-22T12:45:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 149.48},
#  {'id_origen': 'BCN',
#   'ciudad_origen': 'Barcelona',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T15:15:00',
#   'llegada': '2024-11-24T16:40:00',
#   'duracion(min)': 85,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 149.48},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'BCN',
#   'ciudad_destino': 'Barcelona',
#   'salida': '2024-11-22T13:15:00',
#   'llegada': '2024-11-22T14:30:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 153.58},
#  {'id_origen': 'BCN',
#   'ciudad_origen': 'Barcelona',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T15:15:00',
#   'llegada': '2024-11-24T16:40:00',
#   'duracion(min)': 85,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 153.58},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'BCN',
#   'ciudad_destino': 'Barcelona',
#   'salida': '2024-11-22T08:30:00',
#   'llegada': '2024-11-22T09:45:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 141.04},
#  {'id_origen': 'BCN',
#   'ciudad_origen': 'Barcelona',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T15:15:00',
#   'llegada': '2024-11-24T16:40:00',
#   'duracion(min)': 85,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 141.04},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'BCN',
#   'ciudad_destino': 'Barcelona',
#   'salida': '2024-11-22T07:15:00',
#   'llegada': '2024-11-22T08:30:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 133.96},
#  {'id_origen': 'BCN',
#   'ciudad_origen': 'Barcelona',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T20:30:00',
#   'llegada': '2024-11-24T22:00:00',
#   'duracion(min)': 90,
#   'escalas': 0,
#   'aerolinea': 'Vueling Airlines',
#   'precio': 133.96},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'BCN',
#   'ciudad_destino': 'Barcelona',
#   'salida': '2024-11-22T06:45:00',
#   'llegada': '2024-11-22T08:00:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 125.98},
#  {'id_origen': 'BCN',
#   'ciudad_origen': 'Barcelona',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T20:30:00',
#   'llegada': '2024-11-24T22:00:00',
#   'duracion(min)': 90,
#   'escalas': 0,
#   'aerolinea': 'Vueling Airlines',
#   'precio': 125.98},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'BCN',
#   'ciudad_destino': 'Barcelona',
#   'salida': '2024-11-22T15:10:00',
#   'llegada': '2024-11-22T16:35:00',
#   'duracion(min)': 85,
#   'escalas': 0,
#   'aerolinea': 'Air Europa',
#   'precio': 136.22},
#  {'id_origen': 'BCN',
#   'ciudad_origen': 'Barcelona',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T15:15:00',
#   'llegada': '2024-11-24T16:40:00',
#   'duracion(min)': 85,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 136.22},
#  {'id_origen': 'MAD',
#   'ciudad_origen': 'Madrid',
#   'id_destino': 'BCN',
#   'ciudad_destino': 'Barcelona',
#   'salida': '2024-11-22T08:30:00',
#   'llegada': '2024-11-22T09:45:00',
#   'duracion(min)': 75,
#   'escalas': 0,
#   'aerolinea': 'Iberia',
#   'precio': 152},
#  {'id_origen': 'BCN',
#   'ciudad_origen': 'Barcelona',
#   'id_destino': 'MAD',
#   'ciudad_destino': 'Madrid',
#   'salida': '2024-11-24T20:30:00',
#   'llegada': '2024-11-24T22:00:00',
#   'duracion(min)': 90,
#   'escalas': 0,
#   'aerolinea': 'Vueling Airlines',
#   'precio': 152}]

# %%
def crear_df_vuelos(funcion_informacion_vuelos):
    """
    Crea y devuelve un DataFrame a partir de la información de vuelos obtenida.

    La función recibe una lista de diccionarios generada por la función `extraer_informacion_vuelos`, 
    convierte esa lista en un DataFrame y formatea las columnas de "salida" y "llegada" 
    como objetos datetime.

    Args:
        funcion_informacion_vuelos (list[dict]): Lista de diccionarios con información sobre vuelos, 
        obtenida de la función `extraer_informacion_vuelos`.

    Returns:
        pd.DataFrame: Un DataFrame con los datos de vuelos, donde las columnas "salida" y "llegada"
        están formateadas como datetime.
    """

    df_vuelos= pd.DataFrame(funcion_informacion_vuelos)
    df_vuelos["salida"]= pd.to_datetime(df_vuelos["salida"])
    df_vuelos["llegada"]= pd.to_datetime(df_vuelos["llegada"])
    return df_vuelos

# %%
santiago=extraer_informacion_vuelos(vuelo_santiago)
df_vuelos_santiago=crear_df_vuelos(santiago)

# %%
barcelona=extraer_informacion_vuelos(vuelo_barcelona)
df_vuelos_barcelona=crear_df_vuelos(barcelona)

# %%
df_vuelos_santiago.head()
# Out:
#   id_origen           ciudad_origen id_destino          ciudad_destino  \
# 0       MAD                  Madrid        SCQ  Santiago de Compostela
# 1       SCQ  Santiago de Compostela        MAD                  Madrid
# 2       MAD                  Madrid        SCQ  Santiago de Compostela
# 3       SCQ  Santiago de Compostela        MAD                  Madrid
# 4       MAD                  Madrid        SCQ  Santiago de Compostela
#
#                salida             llegada  duracion(min)  escalas aerolinea  \
# 0 2024-11-22 10:55:00 2024-11-22 12:15:00             80        0   Ryanair
# 1 2024-11-24 08:05:00 2024-11-24 09:20:00             75        0   Ryanair
# 2 2024-11-22 11:50:00 2024-11-22 13:05:00             75        0    Iberia
# 3 2024-11-24 13:45:00 2024-11-24 15:00:00             75        0    Iberia
# 4 2024-11-22 07:30:00 2024-11-22 08:45:00             75        0    Iberia
#
#    precio
# 0   88.90
# 1   88.90
# 2  178.94
# 3  178.94
# 4  134.00

# %%
df_vuelos_barcelona.head()
# Out:
#   id_origen ciudad_origen id_destino ciudad_destino              salida  \
# 0       MAD        Madrid        BCN      Barcelona 2024-11-22 07:15:00
# 1       BCN     Barcelona        MAD         Madrid 2024-11-24 15:15:00
# 2       MAD        Madrid        BCN      Barcelona 2024-11-22 10:30:00
# 3       BCN     Barcelona        MAD         Madrid 2024-11-24 15:15:00
# 4       MAD        Madrid        BCN      Barcelona 2024-11-22 06:45:00
#
#               llegada  duracion(min)  escalas aerolinea  precio
# 0 2024-11-22 08:30:00             75        0    Iberia  117.98
# 1 2024-11-24 16:40:00             85        0    Iberia  117.98
# 2 2024-11-22 11:45:00             75        0    Iberia  149.48
# 3 2024-11-24 16:40:00             85        0    Iberia  149.48
# 4 2024-11-22 08:00:00             75        0    Iberia  111.98

# %% [markdown]
# Veamos si es necesario limpiar los archivos

# %%
df_vuelos_santiago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_origen       20 non-null     object
#  1   ciudad_origen   20 non-null     object
#  2   id_destino      20 non-null     object
#  3   ciudad_destino  20 non-null     object
#  4   salida          20 non-null     datetime64[ns]
#  5   llegada         20 non-null     datetime64[ns]
#  6   duracion(min)   20 non-null     int64
#  7   escalas         20 non-null     int64
#  8   aerolinea       20 non-null     object
#  9   precio          20 non-null     float64
# dtypes: datetime64[ns](2), float64(1), int64(2), object(5)
# memory usage: 1.7+ KB

# %%
df_vuelos_barcelona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_origen       20 non-null     object
#  1   ciudad_origen   20 non-null     object
#  2   id_destino      20 non-null     object
#  3   ciudad_destino  20 non-null     object
#  4   salida          20 non-null     datetime64[ns]
#  5   llegada         20 non-null     datetime64[ns]
#  6   duracion(min)   20 non-null     int64
#  7   escalas         20 non-null     int64
#  8   aerolinea       20 non-null     object
#  9   precio          20 non-null     float64
# dtypes: datetime64[ns](2), float64(1), int64(2), object(5)
# memory usage: 1.7+ KB

# %% [markdown]
# No hay valores nulos que tratar, veamos que pasa con los duplicados.

# %%
df_vuelos_santiago.duplicated().value_counts()
# Out:
# False    20
# Name: count, dtype: int64

# %%
df_vuelos_barcelona.duplicated().value_counts()
# Out:
# False    19
# True      1
# Name: count, dtype: int64

# %%
# Tenemos una fila duplicada en cada Data Frame, las eliminamos
df_vuelos_santiago=df_vuelos_santiago.drop_duplicates()
df_vuelos_barcelona=df_vuelos_barcelona.drop_duplicates()
